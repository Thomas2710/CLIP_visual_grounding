# %% [markdown]
# # Extraction of data

# %% [markdown]
# ## Importing the data set from google drive, and unzipping it

# %%
import torch
import numpy as np
from google.colab import drive
import cv2
from matplotlib import pyplot as plt
import os
from PIL import Image, ImageDraw, ImageFont
from tqdm import tqdm
# !pip install ipython-autotime
# %load_ext autotime
#import jdc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.14.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.38)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.18.2
# time: 306 µs (started: 2023-04-28 15:21:07 +00:00)

# %%
# !mkdir dataset
# !gdown 1xijq32XfEm6FPhUb7RsZYWHc2UuwVkiq
# !mv refcocog.tar.gz ./dataset/
# !ls dataset

# !tar -v -xf dataset/refcocog.tar.gz -C dataset
# !ls dataset

os.rename("dataset/refcocog/annotations/refs(umd).p", "dataset/refcocog/annotations/refs_umd.p")
# Out:
# Streaming output truncated to the last 5000 lines.
# ./refcocog/images/COCO_train2014_000000560634.jpg
# ./refcocog/images/COCO_train2014_000000540092.jpg
# ./refcocog/images/COCO_train2014_000000578841.jpg
# ./refcocog/images/COCO_train2014_000000322059.jpg
# ./refcocog/images/COCO_train2014_000000394929.jpg
# ./refcocog/images/COCO_train2014_000000047087.jpg
# ./refcocog/images/COCO_train2014_000000262704.jpg
# ./refcocog/images/COCO_train2014_000000176621.jpg
# ./refcocog/images/COCO_train2014_000000537918.jpg
# ./refcocog/images/COCO_train2014_000000332684.jpg
# ./refcocog/images/COCO_train2014_000000001360.jpg
# ./refcocog/images/COCO_train2014_000000349580.jpg
# ./refcocog/images/COCO_train2014_000000178770.jpg
# ./refcocog/images/COCO_train2014_000000240602.jpg
# ./refcocog/images/COCO_train2014_000000428126.jpg
# ./refcocog/images/COCO_train2014_000000281176.jpg
# ./refcocog/images/COCO_train2014_000000355801.jpg
# ./refcocog/images/COCO_train2014_000000485137.jpg
# ./refcocog/images/COCO_train2014_000000477136.jpg
# ./refcocog/images/COCO_train2014_000000390883.jpg
# ./refcocog/images/COCO_train2014_000000136289.jpg
# ./refcocog/images/COCO_train2014_000000070965.jpg
# ./refcocog/images/COCO_train2014_000000579023.jpg
# ./refcocog/images/COCO_train2014_000000115649.jpg
# ./refcocog/images/COCO_train2014_000000045836.jpg
# ./refcocog/images/COCO_train2014_000000481571.jpg
# ./refcocog/images/COCO_train2014_000000376643.jpg
# ./refcocog/images/COCO_train2014_000000272034.jpg
# ./refcocog/images/COCO_train2014_000000191177.jpg
# ./refcocog/images/COCO_train2014_000000534974.jpg
# ./refcocog/images/COCO_train2014_000000102765.jpg
# ./refcocog/images/COCO_train2014_000000533042.jpg
# ./refcocog/images/COCO_train2014_000000531844.jpg
# ./refcocog/images/COCO_train2014_000000408227.jpg
# ./refcocog/images/COCO_train2014_000000546056.jpg
# ./refcocog/images/COCO_train2014_000000147798.jpg
# ./refcocog/images/COCO_train2014_000000011195.jpg
# ./refcocog/images/COCO_train2014_000000528957.jpg
# ./refcocog/images/COCO_train2014_000000199956.jpg
# ./refcocog/images/COCO_train2014_000000387318.jpg
# ./refcocog/images/COCO_train2014_000000567224.jpg
# ./refcocog/images/COCO_train2014_000000209287.jpg
# ./refcocog/images/COCO_train2014_000000183012.jpg
# ./refcocog/images/COCO_train2014_000000302323.jpg
# ./refcocog/images/COCO_train2014_000000346287.jpg
# ./refcocog/images/COCO_train2014_000000452912.jpg
# ./refcocog/images/COCO_train2014_000000068812.jpg
# ./refcocog/images/COCO_train2014_000000432933.jpg
# ./refcocog/images/COCO_train2014_000000314979.jpg
# ./refcocog/images/COCO_train2014_000000313675.jpg
# ./refcocog/images/COCO_train2014_000000065325.jpg
# ./refcocog/images/COCO_train2014_000000154124.jpg
# ./refcocog/images/COCO_train2014_000000223442.jpg
# ./refcocog/images/COCO_train2014_000000543275.jpg
# ./refcocog/images/COCO_train2014_000000358429.jpg
# ./refcocog/images/COCO_train2014_000000392585.jpg
# ./refcocog/images/COCO_train2014_000000305056.jpg
# ./refcocog/images/COCO_train2014_000000229733.jpg
# ./refcocog/images/COCO_train2014_000000233744.jpg
# ./refcocog/images/COCO_train2014_000000209320.jpg
# ./refcocog/images/COCO_train2014_000000365654.jpg
# ./refcocog/images/COCO_train2014_000000106596.jpg
# ./refcocog/images/COCO_train2014_000000205323.jpg
# ./refcocog/images/COCO_train2014_000000146219.jpg
# ./refcocog/images/COCO_train2014_000000434899.jpg
# ./refcocog/images/COCO_train2014_000000548802.jpg
# ./refcocog/images/COCO_train2014_000000309144.jpg
# ./refcocog/images/COCO_train2014_000000284008.jpg
# ./refcocog/images/COCO_train2014_000000355967.jpg
# ./refcocog/images/COCO_train2014_000000468469.jpg
# ./refcocog/images/COCO_train2014_000000422206.jpg
# ./refcocog/images/COCO_train2014_000000469373.jpg
# ./refcocog/images/COCO_train2014_000000082683.jpg
# ./refcocog/images/COCO_train2014_000000334109.jpg
# ./refcocog/images/COCO_train2014_000000011504.jpg
# ./refcocog/images/COCO_train2014_000000460578.jpg
# ./refcocog/images/COCO_train2014_000000096054.jpg
# ./refcocog/images/COCO_train2014_000000442365.jpg
# ./refcocog/images/COCO_train2014_000000039447.jpg
# ./refcocog/images/COCO_train2014_000000564290.jpg
# ./refcocog/images/COCO_train2014_000000164941.jpg
# ./refcocog/images/COCO_train2014_000000500169.jpg
# ./refcocog/images/COCO_train2014_000000416325.jpg
# ./refcocog/images/COCO_train2014_000000534511.jpg
# ./refcocog/images/COCO_train2014_000000294244.jpg
# ./refcocog/images/COCO_train2014_000000184731.jpg
# ./refcocog/images/COCO_train2014_000000239671.jpg
# ./refcocog/images/COCO_train2014_000000482148.jpg
# ./refcocog/images/COCO_train2014_000000374171.jpg
# ./refcocog/images/COCO_train2014_000000570474.jpg
# ./refcocog/images/COCO_train2014_000000421648.jpg
# ./refcocog/images/COCO_train2014_000000272218.jpg
# ./refcocog/images/COCO_train2014_000000504069.jpg
# ./refcocog/images/COCO_train2014_000000239180.jpg
# ./refcocog/images/COCO_train2014_000000384535.jpg
# ./refcocog/images/COCO_train2014_000000324342.jpg
# ./refcocog/images/COCO_train2014_000000086754.jpg
# ./refcocog/images/COCO_train2014_000000224711.jpg
# ./refcocog/images/COCO_train2014_000000541182.jpg
# ./refcocog/images/COCO_train2014_000000267064.jpg
# ./refcocog/images/COCO_train2014_000000312338.jpg
# ./refcocog/images/COCO_train2014_000000039012.jpg
# ./refcocog/images/COCO_train2014_000000179238.jpg
# ./refcocog/images/COCO_train2014_000000530684.jpg
# ./refcocog/images/COCO_train2014_000000544410.jpg
# ./refcocog/images/COCO_train2014_000000274012.jpg
# ./refcocog/images/COCO_train2014_000000525152.jpg
# ./refcocog/images/COCO_train2014_000000100817.jpg
# ./refcocog/images/COCO_train2014_000000075603.jpg
# ./refcocog/images/COCO_train2014_000000068620.jpg
# ./refcocog/images/COCO_train2014_000000473725.jpg
# ./refcocog/images/COCO_train2014_000000270166.jpg
# ./refcocog/images/COCO_train2014_000000195947.jpg
# ./refcocog/images/COCO_train2014_000000455010.jpg
# ./refcocog/images/COCO_train2014_000000434870.jpg
# ./refcocog/images/COCO_train2014_000000028335.jpg
# ./refcocog/images/COCO_train2014_000000122352.jpg
# ./refcocog/images/COCO_train2014_000000192164.jpg
# ./refcocog/images/COCO_train2014_000000252990.jpg
# ./refcocog/images/COCO_train2014_000000316113.jpg
# ./refcocog/images/COCO_train2014_000000260381.jpg
# ./refcocog/images/COCO_train2014_000000321185.jpg
# ./refcocog/images/COCO_train2014_000000237941.jpg
# ./refcocog/images/COCO_train2014_000000006379.jpg
# ./refcocog/images/COCO_train2014_000000535308.jpg
# ./refcocog/images/COCO_train2014_000000189757.jpg
# ./refcocog/images/COCO_train2014_000000114403.jpg
# ./refcocog/images/COCO_train2014_000000162084.jpg
# ./refcocog/images/COCO_train2014_000000531308.jpg
# ./refcocog/images/COCO_train2014_000000268266.jpg
# ./refcocog/images/COCO_train2014_000000460118.jpg
# ./refcocog/images/COCO_train2014_000000472831.jpg
# ./refcocog/images/COCO_train2014_000000298350.jpg
# ./refcocog/images/COCO_train2014_000000033896.jpg
# ./refcocog/images/COCO_train2014_000000351521.jpg
# ./refcocog/images/COCO_train2014_000000071485.jpg
# ./refcocog/images/COCO_train2014_000000089221.jpg
# ./refcocog/images/COCO_train2014_000000259464.jpg
# ./refcocog/images/COCO_train2014_000000157026.jpg
# ./refcocog/images/COCO_train2014_000000195180.jpg
# ./refcocog/images/COCO_train2014_000000335481.jpg
# ./refcocog/images/COCO_train2014_000000079546.jpg
# ./refcocog/images/COCO_train2014_000000201409.jpg
# ./refcocog/images/COCO_train2014_000000267290.jpg
# ./refcocog/images/COCO_train2014_000000475874.jpg
# ./refcocog/images/COCO_train2014_000000122335.jpg
# ./refcocog/images/COCO_train2014_000000009983.jpg
# ./refcocog/images/COCO_train2014_000000551464.jpg
# ./refcocog/images/COCO_train2014_000000382383.jpg
# ./refcocog/images/COCO_train2014_000000352884.jpg
# ./refcocog/images/COCO_train2014_000000074345.jpg
# ./refcocog/images/COCO_train2014_000000152556.jpg
# ./refcocog/images/COCO_train2014_000000089012.jpg
# ./refcocog/images/COCO_train2014_000000026274.jpg
# ./refcocog/images/COCO_train2014_000000551185.jpg
# ./refcocog/images/COCO_train2014_000000169322.jpg
# ./refcocog/images/COCO_train2014_000000293668.jpg
# ./refcocog/images/COCO_train2014_000000478376.jpg
# ./refcocog/images/COCO_train2014_000000538523.jpg
# ./refcocog/images/COCO_train2014_000000237188.jpg
# ./refcocog/images/COCO_train2014_000000188482.jpg
# ./refcocog/images/COCO_train2014_000000256341.jpg
# ./refcocog/images/COCO_train2014_000000030443.jpg
# ./refcocog/images/COCO_train2014_000000575792.jpg
# ./refcocog/images/COCO_train2014_000000081379.jpg
# ./refcocog/images/COCO_train2014_000000453989.jpg
# ./refcocog/images/COCO_train2014_000000486605.jpg
# ./refcocog/images/COCO_train2014_000000249288.jpg
# ./refcocog/images/COCO_train2014_000000067656.jpg
# ./refcocog/images/COCO_train2014_000000224942.jpg
# ./refcocog/images/COCO_train2014_000000235652.jpg
# ./refcocog/images/COCO_train2014_000000129726.jpg
# ./refcocog/images/COCO_train2014_000000465353.jpg
# ./refcocog/images/COCO_train2014_000000107593.jpg
# ./refcocog/images/COCO_train2014_000000473030.jpg
# ./refcocog/images/COCO_train2014_000000245271.jpg
# ./refcocog/images/COCO_train2014_000000187765.jpg
# ./refcocog/images/COCO_train2014_000000092198.jpg
# ./refcocog/images/COCO_train2014_000000359860.jpg
# ./refcocog/images/COCO_train2014_000000326531.jpg
# ./refcocog/images/COCO_train2014_000000006773.jpg
# ./refcocog/images/COCO_train2014_000000162937.jpg
# ./refcocog/images/COCO_train2014_000000090237.jpg
# ./refcocog/images/COCO_train2014_000000056800.jpg
# ./refcocog/images/COCO_train2014_000000312828.jpg
# ./refcocog/images/COCO_train2014_000000186205.jpg
# ./refcocog/images/COCO_train2014_000000397717.jpg
# ./refcocog/images/COCO_train2014_000000196610.jpg
# ./refcocog/images/COCO_train2014_000000260639.jpg
# ./refcocog/images/COCO_train2014_000000194456.jpg
# ./refcocog/images/COCO_train2014_000000140373.jpg
# ./refcocog/images/COCO_train2014_000000537720.jpg
# ./refcocog/images/COCO_train2014_000000152389.jpg
# ./refcocog/images/COCO_train2014_000000185719.jpg
# ./refcocog/images/COCO_train2014_000000137442.jpg
# ./refcocog/images/COCO_train2014_000000507502.jpg
# ./refcocog/images/COCO_train2014_000000209745.jpg
# ./refcocog/images/COCO_train2014_000000322969.jpg
# ./refcocog/images/COCO_train2014_000000394600.jpg
# ./refcocog/images/COCO_train2014_000000031142.jpg
# ./refcocog/images/COCO_train2014_000000550258.jpg
# ./refcocog/images/COCO_train2014_000000397482.jpg
# ./refcocog/images/COCO_train2014_000000180771.jpg
# ./refcocog/images/COCO_train2014_000000440246.jpg
# ./refcocog/images/COCO_train2014_000000552199.jpg
# ./refcocog/images/COCO_train2014_000000084585.jpg
# ./refcocog/images/COCO_train2014_000000487851.jpg
# ./refcocog/images/COCO_train2014_000000003897.jpg
# ./refcocog/images/COCO_train2014_000000046674.jpg
# ./refcocog/images/COCO_train2014_000000147568.jpg
# ./refcocog/images/COCO_train2014_000000049143.jpg
# ./refcocog/images/COCO_train2014_000000460344.jpg
# ./refcocog/images/COCO_train2014_000000203887.jpg
# ./refcocog/images/COCO_train2014_000000248580.jpg
# ./refcocog/images/COCO_train2014_000000172492.jpg
# ./refcocog/images/COCO_train2014_000000485958.jpg
# ./refcocog/images/COCO_train2014_000000578765.jpg
# ./refcocog/images/COCO_train2014_000000283673.jpg
# ./refcocog/images/COCO_train2014_000000195949.jpg
# ./refcocog/images/COCO_train2014_000000526850.jpg
# ./refcocog/images/COCO_train2014_000000207058.jpg
# ./refcocog/images/COCO_train2014_000000232691.jpg
# ./refcocog/images/COCO_train2014_000000114229.jpg
# ./refcocog/images/COCO_train2014_000000096082.jpg
# ./refcocog/images/COCO_train2014_000000108395.jpg
# ./refcocog/images/COCO_train2014_000000285612.jpg
# ./refcocog/images/COCO_train2014_000000560046.jpg
# ./refcocog/images/COCO_train2014_000000476553.jpg
# ./refcocog/images/COCO_train2014_000000228611.jpg
# ./refcocog/images/COCO_train2014_000000371138.jpg
# ./refcocog/images/COCO_train2014_000000249839.jpg
# ./refcocog/images/COCO_train2014_000000415131.jpg
# ./refcocog/images/COCO_train2014_000000521200.jpg
# ./refcocog/images/COCO_train2014_000000397143.jpg
# ./refcocog/images/COCO_train2014_000000148811.jpg
# ./refcocog/images/COCO_train2014_000000313768.jpg
# ./refcocog/images/COCO_train2014_000000199318.jpg
# ./refcocog/images/COCO_train2014_000000534519.jpg
# ./refcocog/images/COCO_train2014_000000149091.jpg
# ./refcocog/images/COCO_train2014_000000051793.jpg
# ./refcocog/images/COCO_train2014_000000119571.jpg
# ./refcocog/images/COCO_train2014_000000266032.jpg
# ./refcocog/images/COCO_train2014_000000449573.jpg
# ./refcocog/images/COCO_train2014_000000443735.jpg
# ./refcocog/images/COCO_train2014_000000551074.jpg
# ./refcocog/images/COCO_train2014_000000082745.jpg
# ./refcocog/images/COCO_train2014_000000333098.jpg
# ./refcocog/images/COCO_train2014_000000359283.jpg
# ./refcocog/images/COCO_train2014_000000189038.jpg
# ./refcocog/images/COCO_train2014_000000569597.jpg
# ./refcocog/images/COCO_train2014_000000572627.jpg
# ./refcocog/images/COCO_train2014_000000081612.jpg
# ./refcocog/images/COCO_train2014_000000154424.jpg
# ./refcocog/images/COCO_train2014_000000415151.jpg
# ./refcocog/images/COCO_train2014_000000047684.jpg
# ./refcocog/images/COCO_train2014_000000175584.jpg
# ./refcocog/images/COCO_train2014_000000484217.jpg
# ./refcocog/images/COCO_train2014_000000230639.jpg
# ./refcocog/images/COCO_train2014_000000446094.jpg
# ./refcocog/images/COCO_train2014_000000136900.jpg
# ./refcocog/images/COCO_train2014_000000125184.jpg
# ./refcocog/images/COCO_train2014_000000063587.jpg
# ./refcocog/images/COCO_train2014_000000303453.jpg
# ./refcocog/images/COCO_train2014_000000520259.jpg
# ./refcocog/images/COCO_train2014_000000277775.jpg
# ./refcocog/images/COCO_train2014_000000314953.jpg
# ./refcocog/images/COCO_train2014_000000504974.jpg
# ./refcocog/images/COCO_train2014_000000446126.jpg
# ./refcocog/images/COCO_train2014_000000408537.jpg
# ./refcocog/images/COCO_train2014_000000085685.jpg
# ./refcocog/images/COCO_train2014_000000471535.jpg
# ./refcocog/images/COCO_train2014_000000458592.jpg
# ./refcocog/images/COCO_train2014_000000075120.jpg
# ./refcocog/images/COCO_train2014_000000142761.jpg
# ./refcocog/images/COCO_train2014_000000560561.jpg
# ./refcocog/images/COCO_train2014_000000294854.jpg
# ./refcocog/images/COCO_train2014_000000305441.jpg
# ./refcocog/images/COCO_train2014_000000393997.jpg
# ./refcocog/images/COCO_train2014_000000475659.jpg
# ./refcocog/images/COCO_train2014_000000542111.jpg
# ./refcocog/images/COCO_train2014_000000340065.jpg
# ./refcocog/images/COCO_train2014_000000177755.jpg
# ./refcocog/images/COCO_train2014_000000065837.jpg
# ./refcocog/images/COCO_train2014_000000480243.jpg
# ./refcocog/images/COCO_train2014_000000094589.jpg
# ./refcocog/images/COCO_train2014_000000496128.jpg
# ./refcocog/images/COCO_train2014_000000130892.jpg
# ./refcocog/images/COCO_train2014_000000507157.jpg
# ./refcocog/images/COCO_train2014_000000080052.jpg
# ./refcocog/images/COCO_train2014_000000526288.jpg
# ./refcocog/images/COCO_train2014_000000539335.jpg
# ./refcocog/images/COCO_train2014_000000403841.jpg
# ./refcocog/images/COCO_train2014_000000414463.jpg
# ./refcocog/images/COCO_train2014_000000389200.jpg
# ./refcocog/images/COCO_train2014_000000499623.jpg
# ./refcocog/images/COCO_train2014_000000501323.jpg
# ./refcocog/images/COCO_train2014_000000471731.jpg
# ./refcocog/images/COCO_train2014_000000259228.jpg
# ./refcocog/images/COCO_train2014_000000484563.jpg
# ./refcocog/images/COCO_train2014_000000302428.jpg
# ./refcocog/images/COCO_train2014_000000568034.jpg
# ./refcocog/images/COCO_train2014_000000215107.jpg
# ./refcocog/images/COCO_train2014_000000369433.jpg
# ./refcocog/images/COCO_train2014_000000123837.jpg
# ./refcocog/images/COCO_train2014_000000323476.jpg
# ./refcocog/images/COCO_train2014_000000444560.jpg
# ./refcocog/images/COCO_train2014_000000078517.jpg
# ./refcocog/images/COCO_train2014_000000160188.jpg
# ./refcocog/images/COCO_train2014_000000490626.jpg
# ./refcocog/images/COCO_train2014_000000093535.jpg
# ./refcocog/images/COCO_train2014_000000127629.jpg
# ./refcocog/images/COCO_train2014_000000093014.jpg
# ./refcocog/images/COCO_train2014_000000032339.jpg
# ./refcocog/images/COCO_train2014_000000266029.jpg
# ./refcocog/images/COCO_train2014_000000264043.jpg
# ./refcocog/images/COCO_train2014_000000543665.jpg
# ./refcocog/images/COCO_train2014_000000424408.jpg
# ./refcocog/images/COCO_train2014_000000011326.jpg
# ./refcocog/images/COCO_train2014_000000000901.jpg
# ./refcocog/images/COCO_train2014_000000049913.jpg
# ./refcocog/images/COCO_train2014_000000205681.jpg
# ./refcocog/images/COCO_train2014_000000018571.jpg
# ./refcocog/images/COCO_train2014_000000390168.jpg
# ./refcocog/images/COCO_train2014_000000258975.jpg
# ./refcocog/images/COCO_train2014_000000068894.jpg
# ./refcocog/images/COCO_train2014_000000255494.jpg
# ./refcocog/images/COCO_train2014_000000466402.jpg
# ./refcocog/images/COCO_train2014_000000036951.jpg
# ./refcocog/images/COCO_train2014_000000135845.jpg
# ./refcocog/images/COCO_train2014_000000173068.jpg
# ./refcocog/images/COCO_train2014_000000084167.jpg
# ./refcocog/images/COCO_train2014_000000351301.jpg
# ./refcocog/images/COCO_train2014_000000034779.jpg
# ./refcocog/images/COCO_train2014_000000185394.jpg
# ./refcocog/images/COCO_train2014_000000427526.jpg
# ./refcocog/images/COCO_train2014_000000401450.jpg
# ./refcocog/images/COCO_train2014_000000285253.jpg
# ./refcocog/images/COCO_train2014_000000270500.jpg
# ./refcocog/images/COCO_train2014_000000030713.jpg
# ./refcocog/images/COCO_train2014_000000339111.jpg
# ./refcocog/images/COCO_train2014_000000429746.jpg
# ./refcocog/images/COCO_train2014_000000376196.jpg
# ./refcocog/images/COCO_train2014_000000048595.jpg
# ./refcocog/images/COCO_train2014_000000499867.jpg
# ./refcocog/images/COCO_train2014_000000104974.jpg
# ./refcocog/images/COCO_train2014_000000564933.jpg
# ./refcocog/images/COCO_train2014_000000427688.jpg
# ./refcocog/images/COCO_train2014_000000443742.jpg
# ./refcocog/images/COCO_train2014_000000078963.jpg
# ./refcocog/images/COCO_train2014_000000356522.jpg
# ./refcocog/images/COCO_train2014_000000326335.jpg
# ./refcocog/images/COCO_train2014_000000367229.jpg
# ./refcocog/images/COCO_train2014_000000308210.jpg
# ./refcocog/images/COCO_train2014_000000552167.jpg
# ./refcocog/images/COCO_train2014_000000194362.jpg
# ./refcocog/images/COCO_train2014_000000476791.jpg
# ./refcocog/images/COCO_train2014_000000371796.jpg
# ./refcocog/images/COCO_train2014_000000421447.jpg
# ./refcocog/images/COCO_train2014_000000456190.jpg
# ./refcocog/images/COCO_train2014_000000369603.jpg
# ./refcocog/images/COCO_train2014_000000210951.jpg
# ./refcocog/images/COCO_train2014_000000264645.jpg
# ./refcocog/images/COCO_train2014_000000516380.jpg
# ./refcocog/images/COCO_train2014_000000252134.jpg
# ./refcocog/images/COCO_train2014_000000523306.jpg
# ./refcocog/images/COCO_train2014_000000040407.jpg
# ./refcocog/images/COCO_train2014_000000153871.jpg
# ./refcocog/images/COCO_train2014_000000124859.jpg
# ./refcocog/images/COCO_train2014_000000566062.jpg
# ./refcocog/images/COCO_train2014_000000359323.jpg
# ./refcocog/images/COCO_train2014_000000505479.jpg
# ./refcocog/images/COCO_train2014_000000331992.jpg
# ./refcocog/images/COCO_train2014_000000246384.jpg
# ./refcocog/images/COCO_train2014_000000117578.jpg
# ./refcocog/images/COCO_train2014_000000575839.jpg
# ./refcocog/images/COCO_train2014_000000063140.jpg
# ./refcocog/images/COCO_train2014_000000246880.jpg
# ./refcocog/images/COCO_train2014_000000368160.jpg
# ./refcocog/images/COCO_train2014_000000271829.jpg
# ./refcocog/images/COCO_train2014_000000303257.jpg
# ./refcocog/images/COCO_train2014_000000490959.jpg
# ./refcocog/images/COCO_train2014_000000290628.jpg
# ./refcocog/images/COCO_train2014_000000494690.jpg
# ./refcocog/images/COCO_train2014_000000176040.jpg
# ./refcocog/images/COCO_train2014_000000272384.jpg
# ./refcocog/images/COCO_train2014_000000164659.jpg
# ./refcocog/images/COCO_train2014_000000234391.jpg
# ./refcocog/images/COCO_train2014_000000020391.jpg
# ./refcocog/images/COCO_train2014_000000104821.jpg
# ./refcocog/images/COCO_train2014_000000444912.jpg
# ./refcocog/images/COCO_train2014_000000418198.jpg
# ./refcocog/images/COCO_train2014_000000213945.jpg
# ./refcocog/images/COCO_train2014_000000308575.jpg
# ./refcocog/images/COCO_train2014_000000578334.jpg
# ./refcocog/images/COCO_train2014_000000417594.jpg
# ./refcocog/images/COCO_train2014_000000028429.jpg
# ./refcocog/images/COCO_train2014_000000551389.jpg
# ./refcocog/images/COCO_train2014_000000396157.jpg
# ./refcocog/images/COCO_train2014_000000478692.jpg
# ./refcocog/images/COCO_train2014_000000072370.jpg
# ./refcocog/images/COCO_train2014_000000140304.jpg
# ./refcocog/images/COCO_train2014_000000137491.jpg
# ./refcocog/images/COCO_train2014_000000312137.jpg
# ./refcocog/images/COCO_train2014_000000456988.jpg
# ./refcocog/images/COCO_train2014_000000469431.jpg
# ./refcocog/images/COCO_train2014_000000097598.jpg
# ./refcocog/images/COCO_train2014_000000013916.jpg
# ./refcocog/images/COCO_train2014_000000447588.jpg
# ./refcocog/images/COCO_train2014_000000558878.jpg
# ./refcocog/images/COCO_train2014_000000285023.jpg
# ./refcocog/images/COCO_train2014_000000079957.jpg
# ./refcocog/images/COCO_train2014_000000208189.jpg
# ./refcocog/images/COCO_train2014_000000046004.jpg
# ./refcocog/images/COCO_train2014_000000256721.jpg
# ./refcocog/images/COCO_train2014_000000405327.jpg
# ./refcocog/images/COCO_train2014_000000299959.jpg
# ./refcocog/images/COCO_train2014_000000177247.jpg
# ./refcocog/images/COCO_train2014_000000114674.jpg
# ./refcocog/images/COCO_train2014_000000124739.jpg
# ./refcocog/images/COCO_train2014_000000344921.jpg
# ./refcocog/images/COCO_train2014_000000360475.jpg
# ./refcocog/images/COCO_train2014_000000102877.jpg
# ./refcocog/images/COCO_train2014_000000437944.jpg
# ./refcocog/images/COCO_train2014_000000539705.jpg
# ./refcocog/images/COCO_train2014_000000360846.jpg
# ./refcocog/images/COCO_train2014_000000157811.jpg
# ./refcocog/images/COCO_train2014_000000559282.jpg
# ./refcocog/images/COCO_train2014_000000331302.jpg
# ./refcocog/images/COCO_train2014_000000047396.jpg
# ./refcocog/images/COCO_train2014_000000244300.jpg
# ./refcocog/images/COCO_train2014_000000043601.jpg
# ./refcocog/images/COCO_train2014_000000453562.jpg
# ./refcocog/images/COCO_train2014_000000112182.jpg
# ./refcocog/images/COCO_train2014_000000064308.jpg
# ./refcocog/images/COCO_train2014_000000359635.jpg
# ./refcocog/images/COCO_train2014_000000498587.jpg
# ./refcocog/images/COCO_train2014_000000498690.jpg
# ./refcocog/images/COCO_train2014_000000572245.jpg
# ./refcocog/images/COCO_train2014_000000125928.jpg
# ./refcocog/images/COCO_train2014_000000494940.jpg
# ./refcocog/images/COCO_train2014_000000557355.jpg
# ./refcocog/images/COCO_train2014_000000122196.jpg
# ./refcocog/images/COCO_train2014_000000185004.jpg
# ./refcocog/images/COCO_train2014_000000537479.jpg
# ./refcocog/images/COCO_train2014_000000369333.jpg
# ./refcocog/images/COCO_train2014_000000143811.jpg
# ./refcocog/images/COCO_train2014_000000027723.jpg
# ./refcocog/images/COCO_train2014_000000214705.jpg
# ./refcocog/images/COCO_train2014_000000348871.jpg
# ./refcocog/images/COCO_train2014_000000338316.jpg
# ./refcocog/images/COCO_train2014_000000474031.jpg
# ./refcocog/images/COCO_train2014_000000496730.jpg
# ./refcocog/images/COCO_train2014_000000009677.jpg
# ./refcocog/images/COCO_train2014_000000560347.jpg
# ./refcocog/images/COCO_train2014_000000163266.jpg
# ./refcocog/images/COCO_train2014_000000339709.jpg
# ./refcocog/images/COCO_train2014_000000291345.jpg
# ./refcocog/images/COCO_train2014_000000565149.jpg
# ./refcocog/images/COCO_train2014_000000330952.jpg
# ./refcocog/images/COCO_train2014_000000055645.jpg
# ./refcocog/images/COCO_train2014_000000363548.jpg
# ./refcocog/images/COCO_train2014_000000141825.jpg
# ./refcocog/images/COCO_train2014_000000448423.jpg
# ./refcocog/images/COCO_train2014_000000276666.jpg
# ./refcocog/images/COCO_train2014_000000451119.jpg
# ./refcocog/images/COCO_train2014_000000352511.jpg
# ./refcocog/images/COCO_train2014_000000564602.jpg
# ./refcocog/images/COCO_train2014_000000385661.jpg
# ./refcocog/images/COCO_train2014_000000016111.jpg
# ./refcocog/images/COCO_train2014_000000224938.jpg
# ./refcocog/images/COCO_train2014_000000135749.jpg
# ./refcocog/images/COCO_train2014_000000342030.jpg
# ./refcocog/images/COCO_train2014_000000052437.jpg
# ./refcocog/images/COCO_train2014_000000205243.jpg
# ./refcocog/images/COCO_train2014_000000299050.jpg
# ./refcocog/images/COCO_train2014_000000195978.jpg
# ./refcocog/images/COCO_train2014_000000084594.jpg
# ./refcocog/images/COCO_train2014_000000386542.jpg
# ./refcocog/images/COCO_train2014_000000065095.jpg
# ./refcocog/images/COCO_train2014_000000499418.jpg
# ./refcocog/images/COCO_train2014_000000309034.jpg
# ./refcocog/images/COCO_train2014_000000511350.jpg
# ./refcocog/images/COCO_train2014_000000014812.jpg
# ./refcocog/images/COCO_train2014_000000555206.jpg
# ./refcocog/images/COCO_train2014_000000378918.jpg
# ./refcocog/images/COCO_train2014_000000260500.jpg
# ./refcocog/images/COCO_train2014_000000003249.jpg
# ./refcocog/images/COCO_train2014_000000203601.jpg
# ./refcocog/images/COCO_train2014_000000173221.jpg
# ./refcocog/images/COCO_train2014_000000274108.jpg
# ./refcocog/images/COCO_train2014_000000196842.jpg
# ./refcocog/images/COCO_train2014_000000456071.jpg
# ./refcocog/images/COCO_train2014_000000533633.jpg
# ./refcocog/images/COCO_train2014_000000346161.jpg
# ./refcocog/images/COCO_train2014_000000456010.jpg
# ./refcocog/images/COCO_train2014_000000116031.jpg
# ./refcocog/images/COCO_train2014_000000022974.jpg
# ./refcocog/images/COCO_train2014_000000535928.jpg
# ./refcocog/images/COCO_train2014_000000120644.jpg
# ./refcocog/images/COCO_train2014_000000068763.jpg
# ./refcocog/images/COCO_train2014_000000098878.jpg
# ./refcocog/images/COCO_train2014_000000355542.jpg
# ./refcocog/images/COCO_train2014_000000523002.jpg
# ./refcocog/images/COCO_train2014_000000126024.jpg
# ./refcocog/images/COCO_train2014_000000151353.jpg
# ./refcocog/images/COCO_train2014_000000242194.jpg
# ./refcocog/images/COCO_train2014_000000567065.jpg
# ./refcocog/images/COCO_train2014_000000362154.jpg
# ./refcocog/images/COCO_train2014_000000322076.jpg
# ./refcocog/images/COCO_train2014_000000377914.jpg
# ./refcocog/images/COCO_train2014_000000306947.jpg
# ./refcocog/images/COCO_train2014_000000450509.jpg
# ./refcocog/images/COCO_train2014_000000354994.jpg
# ./refcocog/images/COCO_train2014_000000028494.jpg
# ./refcocog/images/COCO_train2014_000000009025.jpg
# ./refcocog/images/COCO_train2014_000000400000.jpg
# ./refcocog/images/COCO_train2014_000000110058.jpg
# ./refcocog/images/COCO_train2014_000000222913.jpg
# ./refcocog/images/COCO_train2014_000000155379.jpg
# ./refcocog/images/COCO_train2014_000000027701.jpg
# ./refcocog/images/COCO_train2014_000000580649.jpg
# ./refcocog/images/COCO_train2014_000000438575.jpg
# ./refcocog/images/COCO_train2014_000000481586.jpg
# ./refcocog/images/COCO_train2014_000000107838.jpg
# ./refcocog/images/COCO_train2014_000000562195.jpg
# ./refcocog/images/COCO_train2014_000000380520.jpg
# ./refcocog/images/COCO_train2014_000000414881.jpg
# ./refcocog/images/COCO_train2014_000000527059.jpg
# ./refcocog/images/COCO_train2014_000000026483.jpg
# ./refcocog/images/COCO_train2014_000000118543.jpg
# ./refcocog/images/COCO_train2014_000000545549.jpg
# ./refcocog/images/COCO_train2014_000000246700.jpg
# ./refcocog/images/COCO_train2014_000000218513.jpg
# ./refcocog/images/COCO_train2014_000000313201.jpg
# ./refcocog/images/COCO_train2014_000000169984.jpg
# ./refcocog/images/COCO_train2014_000000347019.jpg
# ./refcocog/images/COCO_train2014_000000496746.jpg
# ./refcocog/images/COCO_train2014_000000090232.jpg
# ./refcocog/images/COCO_train2014_000000184720.jpg
# ./refcocog/images/COCO_train2014_000000221859.jpg
# ./refcocog/images/COCO_train2014_000000212840.jpg
# ./refcocog/images/COCO_train2014_000000545108.jpg
# ./refcocog/images/COCO_train2014_000000059385.jpg
# ./refcocog/images/COCO_train2014_000000563791.jpg
# ./refcocog/images/COCO_train2014_000000117403.jpg
# ./refcocog/images/COCO_train2014_000000400379.jpg
# ./refcocog/images/COCO_train2014_000000533957.jpg
# ./refcocog/images/COCO_train2014_000000219778.jpg
# ./refcocog/images/COCO_train2014_000000022741.jpg
# ./refcocog/images/COCO_train2014_000000537807.jpg
# ./refcocog/images/COCO_train2014_000000315549.jpg
# ./refcocog/images/COCO_train2014_000000143661.jpg
# ./refcocog/images/COCO_train2014_000000443074.jpg
# ./refcocog/images/COCO_train2014_000000018723.jpg
# ./refcocog/images/COCO_train2014_000000517878.jpg
# ./refcocog/images/COCO_train2014_000000414764.jpg
# ./refcocog/images/COCO_train2014_000000549378.jpg
# ./refcocog/images/COCO_train2014_000000260677.jpg
# ./refcocog/images/COCO_train2014_000000145736.jpg
# ./refcocog/images/COCO_train2014_000000201659.jpg
# ./refcocog/images/COCO_train2014_000000509339.jpg
# ./refcocog/images/COCO_train2014_000000403278.jpg
# ./refcocog/images/COCO_train2014_000000497327.jpg
# ./refcocog/images/COCO_train2014_000000129563.jpg
# ./refcocog/images/COCO_train2014_000000453313.jpg
# ./refcocog/images/COCO_train2014_000000253229.jpg
# ./refcocog/images/COCO_train2014_000000202964.jpg
# ./refcocog/images/COCO_train2014_000000300415.jpg
# ./refcocog/images/COCO_train2014_000000540039.jpg
# ./refcocog/images/COCO_train2014_000000052572.jpg
# ./refcocog/images/COCO_train2014_000000140729.jpg
# ./refcocog/images/COCO_train2014_000000531019.jpg
# ./refcocog/images/COCO_train2014_000000281632.jpg
# ./refcocog/images/COCO_train2014_000000418087.jpg
# ./refcocog/images/COCO_train2014_000000496127.jpg
# ./refcocog/images/COCO_train2014_000000263229.jpg
# ./refcocog/images/COCO_train2014_000000326336.jpg
# ./refcocog/images/COCO_train2014_000000573329.jpg
# ./refcocog/images/COCO_train2014_000000326685.jpg
# ./refcocog/images/COCO_train2014_000000083546.jpg
# ./refcocog/images/COCO_train2014_000000509023.jpg
# ./refcocog/images/COCO_train2014_000000438694.jpg
# ./refcocog/images/COCO_train2014_000000103219.jpg
# ./refcocog/images/COCO_train2014_000000105686.jpg
# ./refcocog/images/COCO_train2014_000000000625.jpg
# ./refcocog/images/COCO_train2014_000000161745.jpg
# ./refcocog/images/COCO_train2014_000000140812.jpg
# ./refcocog/images/COCO_train2014_000000513440.jpg
# ./refcocog/images/COCO_train2014_000000471582.jpg
# ./refcocog/images/COCO_train2014_000000329368.jpg
# ./refcocog/images/COCO_train2014_000000452694.jpg
# ./refcocog/images/COCO_train2014_000000184908.jpg
# ./refcocog/images/COCO_train2014_000000341596.jpg
# ./refcocog/images/COCO_train2014_000000386029.jpg
# ./refcocog/images/COCO_train2014_000000128567.jpg
# ./refcocog/images/COCO_train2014_000000306089.jpg
# ./refcocog/images/COCO_train2014_000000073892.jpg
# ./refcocog/images/COCO_train2014_000000575121.jpg
# ./refcocog/images/COCO_train2014_000000540203.jpg
# ./refcocog/images/COCO_train2014_000000094558.jpg
# ./refcocog/images/COCO_train2014_000000096679.jpg
# ./refcocog/images/COCO_train2014_000000334911.jpg
# ./refcocog/images/COCO_train2014_000000389914.jpg
# ./refcocog/images/COCO_train2014_000000125270.jpg
# ./refcocog/images/COCO_train2014_000000572572.jpg
# ./refcocog/images/COCO_train2014_000000324049.jpg
# ./refcocog/images/COCO_train2014_000000518098.jpg
# ./refcocog/images/COCO_train2014_000000385448.jpg
# ./refcocog/images/COCO_train2014_000000223499.jpg
# ./refcocog/images/COCO_train2014_000000566099.jpg
# ./refcocog/images/COCO_train2014_000000257617.jpg
# ./refcocog/images/COCO_train2014_000000442400.jpg
# ./refcocog/images/COCO_train2014_000000222086.jpg
# ./refcocog/images/COCO_train2014_000000087616.jpg
# ./refcocog/images/COCO_train2014_000000185494.jpg
# ./refcocog/images/COCO_train2014_000000329480.jpg
# ./refcocog/images/COCO_train2014_000000297210.jpg
# ./refcocog/images/COCO_train2014_000000014835.jpg
# ./refcocog/images/COCO_train2014_000000006721.jpg
# ./refcocog/images/COCO_train2014_000000148215.jpg
# ./refcocog/images/COCO_train2014_000000286742.jpg
# ./refcocog/images/COCO_train2014_000000513852.jpg
# ./refcocog/images/COCO_train2014_000000173185.jpg
# ./refcocog/images/COCO_train2014_000000079441.jpg
# ./refcocog/images/COCO_train2014_000000284348.jpg
# ./refcocog/images/COCO_train2014_000000160302.jpg
# ./refcocog/images/COCO_train2014_000000008186.jpg
# ./refcocog/images/COCO_train2014_000000409774.jpg
# ./refcocog/images/COCO_train2014_000000278335.jpg
# ./refcocog/images/COCO_train2014_000000151587.jpg
# ./refcocog/images/COCO_train2014_000000047833.jpg
# ./refcocog/images/COCO_train2014_000000220864.jpg
# ./refcocog/images/COCO_train2014_000000166506.jpg
# ./refcocog/images/COCO_train2014_000000318468.jpg
# ./refcocog/images/COCO_train2014_000000025533.jpg
# ./refcocog/images/COCO_train2014_000000559090.jpg
# ./refcocog/images/COCO_train2014_000000073650.jpg
# ./refcocog/images/COCO_train2014_000000512211.jpg
# ./refcocog/images/COCO_train2014_000000305476.jpg
# ./refcocog/images/COCO_train2014_000000479219.jpg
# ./refcocog/images/COCO_train2014_000000055232.jpg
# ./refcocog/images/COCO_train2014_000000503153.jpg
# ./refcocog/images/COCO_train2014_000000230210.jpg
# ./refcocog/images/COCO_train2014_000000178244.jpg
# ./refcocog/images/COCO_train2014_000000577051.jpg
# ./refcocog/images/COCO_train2014_000000084845.jpg
# ./refcocog/images/COCO_train2014_000000045768.jpg
# ./refcocog/images/COCO_train2014_000000372971.jpg
# ./refcocog/images/COCO_train2014_000000082759.jpg
# ./refcocog/images/COCO_train2014_000000158863.jpg
# ./refcocog/images/COCO_train2014_000000420366.jpg
# ./refcocog/images/COCO_train2014_000000173751.jpg
# ./refcocog/images/COCO_train2014_000000349791.jpg
# ./refcocog/images/COCO_train2014_000000246491.jpg
# ./refcocog/images/COCO_train2014_000000417715.jpg
# ./refcocog/images/COCO_train2014_000000010925.jpg
# ./refcocog/images/COCO_train2014_000000332965.jpg
# ./refcocog/images/COCO_train2014_000000462298.jpg
# ./refcocog/images/COCO_train2014_000000008369.jpg
# ./refcocog/images/COCO_train2014_000000484074.jpg
# ./refcocog/images/COCO_train2014_000000343307.jpg
# ./refcocog/images/COCO_train2014_000000318384.jpg
# ./refcocog/images/COCO_train2014_000000127360.jpg
# ./refcocog/images/COCO_train2014_000000578108.jpg
# ./refcocog/images/COCO_train2014_000000505092.jpg
# ./refcocog/images/COCO_train2014_000000365066.jpg
# ./refcocog/images/COCO_train2014_000000200133.jpg
# ./refcocog/images/COCO_train2014_000000365027.jpg
# ./refcocog/images/COCO_train2014_000000323498.jpg
# ./refcocog/images/COCO_train2014_000000049331.jpg
# ./refcocog/images/COCO_train2014_000000220922.jpg
# ./refcocog/images/COCO_train2014_000000275612.jpg
# ./refcocog/images/COCO_train2014_000000134454.jpg
# ./refcocog/images/COCO_train2014_000000483806.jpg
# ./refcocog/images/COCO_train2014_000000226639.jpg
# ./refcocog/images/COCO_train2014_000000168657.jpg
# ./refcocog/images/COCO_train2014_000000245392.jpg
# ./refcocog/images/COCO_train2014_000000062209.jpg
# ./refcocog/images/COCO_train2014_000000490735.jpg
# ./refcocog/images/COCO_train2014_000000003729.jpg
# ./refcocog/images/COCO_train2014_000000144283.jpg
# ./refcocog/images/COCO_train2014_000000560563.jpg
# ./refcocog/images/COCO_train2014_000000477154.jpg
# ./refcocog/images/COCO_train2014_000000463702.jpg
# ./refcocog/images/COCO_train2014_000000355922.jpg
# ./refcocog/images/COCO_train2014_000000092217.jpg
# ./refcocog/images/COCO_train2014_000000421623.jpg
# ./refcocog/images/COCO_train2014_000000190241.jpg
# ./refcocog/images/COCO_train2014_000000444660.jpg
# ./refcocog/images/COCO_train2014_000000069514.jpg
# ./refcocog/images/COCO_train2014_000000563280.jpg
# ./refcocog/images/COCO_train2014_000000531814.jpg
# ./refcocog/images/COCO_train2014_000000181084.jpg
# ./refcocog/images/COCO_train2014_000000178184.jpg
# ./refcocog/images/COCO_train2014_000000375568.jpg
# ./refcocog/images/COCO_train2014_000000041950.jpg
# ./refcocog/images/COCO_train2014_000000167482.jpg
# ./refcocog/images/COCO_train2014_000000303236.jpg
# ./refcocog/images/COCO_train2014_000000009180.jpg
# ./refcocog/images/COCO_train2014_000000175693.jpg
# ./refcocog/images/COCO_train2014_000000473587.jpg
# ./refcocog/images/COCO_train2014_000000027149.jpg
# ./refcocog/images/COCO_train2014_000000411263.jpg
# ./refcocog/images/COCO_train2014_000000303815.jpg
# ./refcocog/images/COCO_train2014_000000207363.jpg
# ./refcocog/images/COCO_train2014_000000148841.jpg
# ./refcocog/images/COCO_train2014_000000336002.jpg
# ./refcocog/images/COCO_train2014_000000324442.jpg
# ./refcocog/images/COCO_train2014_000000208274.jpg
# ./refcocog/images/COCO_train2014_000000489352.jpg
# ./refcocog/images/COCO_train2014_000000572441.jpg
# ./refcocog/images/COCO_train2014_000000282173.jpg
# ./refcocog/images/COCO_train2014_000000279747.jpg
# ./refcocog/images/COCO_train2014_000000519490.jpg
# ./refcocog/images/COCO_train2014_000000106774.jpg
# ./refcocog/images/COCO_train2014_000000558705.jpg
# ./refcocog/images/COCO_train2014_000000046042.jpg
# ./refcocog/images/COCO_train2014_000000358620.jpg
# ./refcocog/images/COCO_train2014_000000402364.jpg
# ./refcocog/images/COCO_train2014_000000239520.jpg
# ./refcocog/images/COCO_train2014_000000485064.jpg
# ./refcocog/images/COCO_train2014_000000406275.jpg
# ./refcocog/images/COCO_train2014_000000256950.jpg
# ./refcocog/images/COCO_train2014_000000072258.jpg
# ./refcocog/images/COCO_train2014_000000045974.jpg
# ./refcocog/images/COCO_train2014_000000092411.jpg
# ./refcocog/images/COCO_train2014_000000023066.jpg
# ./refcocog/images/COCO_train2014_000000275511.jpg
# ./refcocog/images/COCO_train2014_000000068867.jpg
# ./refcocog/images/COCO_train2014_000000259629.jpg
# ./refcocog/images/COCO_train2014_000000143777.jpg
# ./refcocog/images/COCO_train2014_000000030345.jpg
# ./refcocog/images/COCO_train2014_000000104482.jpg
# ./refcocog/images/COCO_train2014_000000469495.jpg
# ./refcocog/images/COCO_train2014_000000438145.jpg
# ./refcocog/images/COCO_train2014_000000578884.jpg
# ./refcocog/images/COCO_train2014_000000027298.jpg
# ./refcocog/images/COCO_train2014_000000472266.jpg
# ./refcocog/images/COCO_train2014_000000225517.jpg
# ./refcocog/images/COCO_train2014_000000188630.jpg
# ./refcocog/images/COCO_train2014_000000394921.jpg
# ./refcocog/images/COCO_train2014_000000088208.jpg
# ./refcocog/images/COCO_train2014_000000403184.jpg
# ./refcocog/images/COCO_train2014_000000528321.jpg
# ./refcocog/images/COCO_train2014_000000410425.jpg
# ./refcocog/images/COCO_train2014_000000040165.jpg
# ./refcocog/images/COCO_train2014_000000489476.jpg
# ./refcocog/images/COCO_train2014_000000400726.jpg
# ./refcocog/images/COCO_train2014_000000303723.jpg
# ./refcocog/images/COCO_train2014_000000166376.jpg
# ./refcocog/images/COCO_train2014_000000527139.jpg
# ./refcocog/images/COCO_train2014_000000229559.jpg
# ./refcocog/images/COCO_train2014_000000439527.jpg
# ./refcocog/images/COCO_train2014_000000384883.jpg
# ./refcocog/images/COCO_train2014_000000543717.jpg
# ./refcocog/images/COCO_train2014_000000491778.jpg
# ./refcocog/images/COCO_train2014_000000231631.jpg
# ./refcocog/images/COCO_train2014_000000038582.jpg
# ./refcocog/images/COCO_train2014_000000381000.jpg
# ./refcocog/images/COCO_train2014_000000041252.jpg
# ./refcocog/images/COCO_train2014_000000388403.jpg
# ./refcocog/images/COCO_train2014_000000574094.jpg
# ./refcocog/images/COCO_train2014_000000456392.jpg
# ./refcocog/images/COCO_train2014_000000280189.jpg
# ./refcocog/images/COCO_train2014_000000238982.jpg
# ./refcocog/images/COCO_train2014_000000134912.jpg
# ./refcocog/images/COCO_train2014_000000514269.jpg
# ./refcocog/images/COCO_train2014_000000425439.jpg
# ./refcocog/images/COCO_train2014_000000483175.jpg
# ./refcocog/images/COCO_train2014_000000170440.jpg
# ./refcocog/images/COCO_train2014_000000149192.jpg
# ./refcocog/images/COCO_train2014_000000350737.jpg
# ./refcocog/images/COCO_train2014_000000360575.jpg
# ./refcocog/images/COCO_train2014_000000192642.jpg
# ./refcocog/images/COCO_train2014_000000200138.jpg
# ./refcocog/images/COCO_train2014_000000266749.jpg
# ./refcocog/images/COCO_train2014_000000143900.jpg
# ./refcocog/images/COCO_train2014_000000444315.jpg
# ./refcocog/images/COCO_train2014_000000561352.jpg
# ./refcocog/images/COCO_train2014_000000142402.jpg
# ./refcocog/images/COCO_train2014_000000117991.jpg
# ./refcocog/images/COCO_train2014_000000524041.jpg
# ./refcocog/images/COCO_train2014_000000047388.jpg
# ./refcocog/images/COCO_train2014_000000550839.jpg
# ./refcocog/images/COCO_train2014_000000576413.jpg
# ./refcocog/images/COCO_train2014_000000140954.jpg
# ./refcocog/images/COCO_train2014_000000148828.jpg
# ./refcocog/images/COCO_train2014_000000049301.jpg
# ./refcocog/images/COCO_train2014_000000298303.jpg
# ./refcocog/images/COCO_train2014_000000515019.jpg
# ./refcocog/images/COCO_train2014_000000137386.jpg
# ./refcocog/images/COCO_train2014_000000224190.jpg
# ./refcocog/images/COCO_train2014_000000175476.jpg
# ./refcocog/images/COCO_train2014_000000480666.jpg
# ./refcocog/images/COCO_train2014_000000299163.jpg
# ./refcocog/images/COCO_train2014_000000439299.jpg
# ./refcocog/images/COCO_train2014_000000341232.jpg
# ./refcocog/images/COCO_train2014_000000154648.jpg
# ./refcocog/images/COCO_train2014_000000044167.jpg
# ./refcocog/images/COCO_train2014_000000234457.jpg
# ./refcocog/images/COCO_train2014_000000478818.jpg
# ./refcocog/images/COCO_train2014_000000481091.jpg
# ./refcocog/images/COCO_train2014_000000307092.jpg
# ./refcocog/images/COCO_train2014_000000028525.jpg
# ./refcocog/images/COCO_train2014_000000103699.jpg
# ./refcocog/images/COCO_train2014_000000238589.jpg
# ./refcocog/images/COCO_train2014_000000186116.jpg
# ./refcocog/images/COCO_train2014_000000267203.jpg
# ./refcocog/images/COCO_train2014_000000183398.jpg
# ./refcocog/images/COCO_train2014_000000378521.jpg
# ./refcocog/images/COCO_train2014_000000317292.jpg
# ./refcocog/images/COCO_train2014_000000461181.jpg
# ./refcocog/images/COCO_train2014_000000389793.jpg
# ./refcocog/images/COCO_train2014_000000490830.jpg
# ./refcocog/images/COCO_train2014_000000064501.jpg
# ./refcocog/images/COCO_train2014_000000353709.jpg
# ./refcocog/images/COCO_train2014_000000197307.jpg
# ./refcocog/images/COCO_train2014_000000569046.jpg
# ./refcocog/images/COCO_train2014_000000549236.jpg
# ./refcocog/images/COCO_train2014_000000300624.jpg
# ./refcocog/images/COCO_train2014_000000213366.jpg
# ./refcocog/images/COCO_train2014_000000017962.jpg
# ./refcocog/images/COCO_train2014_000000427178.jpg
# ./refcocog/images/COCO_train2014_000000376875.jpg
# ./refcocog/images/COCO_train2014_000000526887.jpg
# ./refcocog/images/COCO_train2014_000000538957.jpg
# ./refcocog/images/COCO_train2014_000000275741.jpg
# ./refcocog/images/COCO_train2014_000000378278.jpg
# ./refcocog/images/COCO_train2014_000000561172.jpg
# ./refcocog/images/COCO_train2014_000000347884.jpg
# ./refcocog/images/COCO_train2014_000000517947.jpg
# ./refcocog/images/COCO_train2014_000000037579.jpg
# ./refcocog/images/COCO_train2014_000000187442.jpg
# ./refcocog/images/COCO_train2014_000000022451.jpg
# ./refcocog/images/COCO_train2014_000000476191.jpg
# ./refcocog/images/COCO_train2014_000000461787.jpg
# ./refcocog/images/COCO_train2014_000000346061.jpg
# ./refcocog/images/COCO_train2014_000000264356.jpg
# ./refcocog/images/COCO_train2014_000000542488.jpg
# ./refcocog/images/COCO_train2014_000000032644.jpg
# ./refcocog/images/COCO_train2014_000000510314.jpg
# ./refcocog/images/COCO_train2014_000000157989.jpg
# ./refcocog/images/COCO_train2014_000000176923.jpg
# ./refcocog/images/COCO_train2014_000000484158.jpg
# ./refcocog/images/COCO_train2014_000000415464.jpg
# ./refcocog/images/COCO_train2014_000000061052.jpg
# ./refcocog/images/COCO_train2014_000000394992.jpg
# ./refcocog/images/COCO_train2014_000000412330.jpg
# ./refcocog/images/COCO_train2014_000000062743.jpg
# ./refcocog/images/COCO_train2014_000000176461.jpg
# ./refcocog/images/COCO_train2014_000000077399.jpg
# ./refcocog/images/COCO_train2014_000000421630.jpg
# ./refcocog/images/COCO_train2014_000000282583.jpg
# ./refcocog/images/COCO_train2014_000000319160.jpg
# ./refcocog/images/COCO_train2014_000000120717.jpg
# ./refcocog/images/COCO_train2014_000000533356.jpg
# ./refcocog/images/COCO_train2014_000000456201.jpg
# ./refcocog/images/COCO_train2014_000000022484.jpg
# ./refcocog/images/COCO_train2014_000000021353.jpg
# ./refcocog/images/COCO_train2014_000000248029.jpg
# ./refcocog/images/COCO_train2014_000000550747.jpg
# ./refcocog/images/COCO_train2014_000000070285.jpg
# ./refcocog/images/COCO_train2014_000000139075.jpg
# ./refcocog/images/COCO_train2014_000000021260.jpg
# ./refcocog/images/COCO_train2014_000000426947.jpg
# ./refcocog/images/COCO_train2014_000000325470.jpg
# ./refcocog/images/COCO_train2014_000000427396.jpg
# ./refcocog/images/COCO_train2014_000000084273.jpg
# ./refcocog/images/COCO_train2014_000000168955.jpg
# ./refcocog/images/COCO_train2014_000000412222.jpg
# ./refcocog/images/COCO_train2014_000000514945.jpg
# ./refcocog/images/COCO_train2014_000000031540.jpg
# ./refcocog/images/COCO_train2014_000000363336.jpg
# ./refcocog/images/COCO_train2014_000000097369.jpg
# ./refcocog/images/COCO_train2014_000000464322.jpg
# ./refcocog/images/COCO_train2014_000000396030.jpg
# ./refcocog/images/COCO_train2014_000000534297.jpg
# ./refcocog/images/COCO_train2014_000000539101.jpg
# ./refcocog/images/COCO_train2014_000000247049.jpg
# ./refcocog/images/COCO_train2014_000000405316.jpg
# ./refcocog/images/COCO_train2014_000000490947.jpg
# ./refcocog/images/COCO_train2014_000000297527.jpg
# ./refcocog/images/COCO_train2014_000000198423.jpg
# ./refcocog/images/COCO_train2014_000000252596.jpg
# ./refcocog/images/COCO_train2014_000000125036.jpg
# ./refcocog/images/COCO_train2014_000000475527.jpg
# ./refcocog/images/COCO_train2014_000000114698.jpg
# ./refcocog/images/COCO_train2014_000000097095.jpg
# ./refcocog/images/COCO_train2014_000000391538.jpg
# ./refcocog/images/COCO_train2014_000000217623.jpg
# ./refcocog/images/COCO_train2014_000000193034.jpg
# ./refcocog/images/COCO_train2014_000000091348.jpg
# ./refcocog/images/COCO_train2014_000000106754.jpg
# ./refcocog/images/COCO_train2014_000000366417.jpg
# ./refcocog/images/COCO_train2014_000000396812.jpg
# ./refcocog/images/COCO_train2014_000000398757.jpg
# ./refcocog/images/COCO_train2014_000000485907.jpg
# ./refcocog/images/COCO_train2014_000000418030.jpg
# ./refcocog/images/COCO_train2014_000000528583.jpg
# ./refcocog/images/COCO_train2014_000000373964.jpg
# ./refcocog/images/COCO_train2014_000000322852.jpg
# ./refcocog/images/COCO_train2014_000000550308.jpg
# ./refcocog/images/COCO_train2014_000000359537.jpg
# ./refcocog/images/COCO_train2014_000000257804.jpg
# ./refcocog/images/COCO_train2014_000000320117.jpg
# ./refcocog/images/COCO_train2014_000000467432.jpg
# ./refcocog/images/COCO_train2014_000000460491.jpg
# ./refcocog/images/COCO_train2014_000000240339.jpg
# ./refcocog/images/COCO_train2014_000000185646.jpg
# ./refcocog/images/COCO_train2014_000000562100.jpg
# ./refcocog/images/COCO_train2014_000000349560.jpg
# ./refcocog/images/COCO_train2014_000000187371.jpg
# ./refcocog/images/COCO_train2014_000000179698.jpg
# ./refcocog/images/COCO_train2014_000000578856.jpg
# ./refcocog/images/COCO_train2014_000000302543.jpg
# ./refcocog/images/COCO_train2014_000000573807.jpg
# ./refcocog/images/COCO_train2014_000000329993.jpg
# ./refcocog/images/COCO_train2014_000000521112.jpg
# ./refcocog/images/COCO_train2014_000000132913.jpg
# ./refcocog/images/COCO_train2014_000000343574.jpg
# ./refcocog/images/COCO_train2014_000000234244.jpg
# ./refcocog/images/COCO_train2014_000000457519.jpg
# ./refcocog/images/COCO_train2014_000000537825.jpg
# ./refcocog/images/COCO_train2014_000000174356.jpg
# ./refcocog/images/COCO_train2014_000000216539.jpg
# ./refcocog/images/COCO_train2014_000000080147.jpg
# ./refcocog/images/COCO_train2014_000000277778.jpg
# ./refcocog/images/COCO_train2014_000000247919.jpg
# ./refcocog/images/COCO_train2014_000000246089.jpg
# ./refcocog/images/COCO_train2014_000000246085.jpg
# ./refcocog/images/COCO_train2014_000000499305.jpg
# ./refcocog/images/COCO_train2014_000000099636.jpg
# ./refcocog/images/COCO_train2014_000000183350.jpg
# ./refcocog/images/COCO_train2014_000000299618.jpg
# ./refcocog/images/COCO_train2014_000000430688.jpg
# ./refcocog/images/COCO_train2014_000000368746.jpg
# ./refcocog/images/COCO_train2014_000000093127.jpg
# ./refcocog/images/COCO_train2014_000000313655.jpg
# ./refcocog/images/COCO_train2014_000000349827.jpg
# ./refcocog/images/COCO_train2014_000000029154.jpg
# ./refcocog/images/COCO_train2014_000000243160.jpg
# ./refcocog/images/COCO_train2014_000000502482.jpg
# ./refcocog/images/COCO_train2014_000000226524.jpg
# ./refcocog/images/COCO_train2014_000000269343.jpg
# ./refcocog/images/COCO_train2014_000000535136.jpg
# ./refcocog/images/COCO_train2014_000000329587.jpg
# ./refcocog/images/COCO_train2014_000000167927.jpg
# ./refcocog/images/COCO_train2014_000000199131.jpg
# ./refcocog/images/COCO_train2014_000000282425.jpg
# ./refcocog/images/COCO_train2014_000000225719.jpg
# ./refcocog/images/COCO_train2014_000000504861.jpg
# ./refcocog/images/COCO_train2014_000000561821.jpg
# ./refcocog/images/COCO_train2014_000000350585.jpg
# ./refcocog/images/COCO_train2014_000000214232.jpg
# ./refcocog/images/COCO_train2014_000000289326.jpg
# ./refcocog/images/COCO_train2014_000000418988.jpg
# ./refcocog/images/COCO_train2014_000000312841.jpg
# ./refcocog/images/COCO_train2014_000000536964.jpg
# ...
# ./refcocog/images/COCO_train2014_000000133835.jpg
# ./refcocog/images/COCO_train2014_000000428381.jpg
# ./refcocog/images/COCO_train2014_000000228678.jpg
# ./refcocog/images/COCO_train2014_000000162199.jpg
# ./refcocog/images/COCO_train2014_000000323963.jpg
# ./refcocog/images/COCO_train2014_000000077055.jpg
# ./refcocog/images/COCO_train2014_000000547745.jpg
# ./refcocog/images/COCO_train2014_000000161941.jpg
# ./refcocog/images/COCO_train2014_000000337147.jpg
# ./refcocog/images/COCO_train2014_000000266209.jpg
# ./refcocog/images/COCO_train2014_000000451588.jpg
# ./refcocog/images/COCO_train2014_000000411913.jpg
# ./refcocog/images/COCO_train2014_000000469825.jpg
# ./refcocog/images/COCO_train2014_000000001792.jpg
# ./refcocog/images/COCO_train2014_000000242712.jpg
# ./refcocog/images/COCO_train2014_000000468818.jpg
# ./refcocog/images/COCO_train2014_000000131511.jpg
# ./refcocog/images/COCO_train2014_000000431407.jpg
# ./refcocog/images/COCO_train2014_000000268310.jpg
# ./refcocog/images/COCO_train2014_000000286930.jpg
# ./refcocog/images/COCO_train2014_000000268901.jpg
# ./refcocog/images/COCO_train2014_000000045946.jpg
# ./refcocog/images/COCO_train2014_000000241204.jpg
# ./refcocog/images/COCO_train2014_000000213241.jpg
# ./refcocog/images/COCO_train2014_000000027711.jpg
# ./refcocog/images/COCO_train2014_000000391162.jpg
# ./refcocog/images/COCO_train2014_000000580906.jpg
# ./refcocog/images/COCO_train2014_000000194030.jpg
# ./refcocog/images/COCO_train2014_000000106756.jpg
# ./refcocog/images/COCO_train2014_000000384316.jpg
# ./refcocog/images/COCO_train2014_000000206082.jpg
# ./refcocog/images/COCO_train2014_000000292579.jpg
# ./refcocog/images/COCO_train2014_000000432897.jpg
# ./refcocog/images/COCO_train2014_000000053977.jpg
# ./refcocog/images/COCO_train2014_000000109169.jpg
# ./refcocog/images/COCO_train2014_000000364090.jpg
# ./refcocog/images/COCO_train2014_000000049357.jpg
# ./refcocog/images/COCO_train2014_000000422528.jpg
# ./refcocog/images/COCO_train2014_000000050031.jpg
# ./refcocog/images/COCO_train2014_000000420606.jpg
# ./refcocog/images/COCO_train2014_000000137134.jpg
# ./refcocog/images/COCO_train2014_000000212914.jpg
# ./refcocog/images/COCO_train2014_000000248419.jpg
# ./refcocog/images/COCO_train2014_000000314647.jpg
# ./refcocog/images/COCO_train2014_000000348595.jpg
# ./refcocog/images/COCO_train2014_000000379579.jpg
# ./refcocog/images/COCO_train2014_000000077662.jpg
# ./refcocog/images/COCO_train2014_000000499786.jpg
# ./refcocog/images/COCO_train2014_000000030187.jpg
# ./refcocog/images/COCO_train2014_000000314259.jpg
# ./refcocog/images/COCO_train2014_000000289071.jpg
# ./refcocog/images/COCO_train2014_000000461333.jpg
# ./refcocog/images/COCO_train2014_000000329182.jpg
# ./refcocog/images/COCO_train2014_000000529095.jpg
# ./refcocog/images/COCO_train2014_000000566955.jpg
# ./refcocog/images/COCO_train2014_000000430396.jpg
# ./refcocog/images/COCO_train2014_000000511736.jpg
# ./refcocog/images/COCO_train2014_000000125348.jpg
# ./refcocog/images/COCO_train2014_000000143140.jpg
# ./refcocog/images/COCO_train2014_000000167525.jpg
# ./refcocog/images/COCO_train2014_000000035230.jpg
# ./refcocog/images/COCO_train2014_000000381244.jpg
# ./refcocog/images/COCO_train2014_000000058106.jpg
# ./refcocog/images/COCO_train2014_000000403577.jpg
# ./refcocog/images/COCO_train2014_000000234569.jpg
# ./refcocog/images/COCO_train2014_000000234255.jpg
# ./refcocog/images/COCO_train2014_000000226374.jpg
# ./refcocog/images/COCO_train2014_000000058731.jpg
# ./refcocog/images/COCO_train2014_000000529840.jpg
# ./refcocog/images/COCO_train2014_000000554486.jpg
# ./refcocog/images/COCO_train2014_000000491450.jpg
# ./refcocog/images/COCO_train2014_000000081715.jpg
# ./refcocog/images/COCO_train2014_000000233341.jpg
# ./refcocog/images/COCO_train2014_000000161705.jpg
# ./refcocog/images/COCO_train2014_000000486186.jpg
# ./refcocog/images/COCO_train2014_000000547267.jpg
# ./refcocog/images/COCO_train2014_000000010484.jpg
# ./refcocog/images/COCO_train2014_000000072466.jpg
# ./refcocog/images/COCO_train2014_000000050883.jpg
# ./refcocog/images/COCO_train2014_000000454422.jpg
# ./refcocog/images/COCO_train2014_000000274949.jpg
# ./refcocog/images/COCO_train2014_000000334048.jpg
# ./refcocog/images/COCO_train2014_000000373623.jpg
# ./refcocog/images/COCO_train2014_000000505827.jpg
# ./refcocog/images/COCO_train2014_000000579491.jpg
# ./refcocog/images/COCO_train2014_000000281371.jpg
# ./refcocog/images/COCO_train2014_000000110869.jpg
# ./refcocog/images/COCO_train2014_000000511301.jpg
# ./refcocog/images/COCO_train2014_000000068030.jpg
# ./refcocog/images/COCO_train2014_000000577650.jpg
# ./refcocog/images/COCO_train2014_000000013000.jpg
# ./refcocog/images/COCO_train2014_000000023594.jpg
# ./refcocog/images/COCO_train2014_000000417218.jpg
# ./refcocog/images/COCO_train2014_000000000030.jpg
# ./refcocog/images/COCO_train2014_000000549639.jpg
# ./refcocog/images/COCO_train2014_000000230127.jpg
# ./refcocog/images/COCO_train2014_000000354546.jpg
# ./refcocog/images/COCO_train2014_000000509235.jpg
# ./refcocog/images/COCO_train2014_000000159176.jpg
# ./refcocog/images/COCO_train2014_000000203380.jpg
# ./refcocog/images/COCO_train2014_000000007689.jpg
# ./refcocog/images/COCO_train2014_000000233404.jpg
# ./refcocog/images/COCO_train2014_000000058677.jpg
# ./refcocog/images/COCO_train2014_000000197573.jpg
# ./refcocog/images/COCO_train2014_000000340488.jpg
# ./refcocog/images/COCO_train2014_000000188276.jpg
# ./refcocog/images/COCO_train2014_000000039791.jpg
# ./refcocog/images/COCO_train2014_000000155839.jpg
# ./refcocog/images/COCO_train2014_000000420316.jpg
# ./refcocog/images/COCO_train2014_000000312744.jpg
# ./refcocog/images/COCO_train2014_000000221055.jpg
# ./refcocog/images/COCO_train2014_000000197057.jpg
# ./refcocog/images/COCO_train2014_000000234672.jpg
# ./refcocog/images/COCO_train2014_000000173196.jpg
# ./refcocog/images/COCO_train2014_000000376384.jpg
# ./refcocog/images/COCO_train2014_000000323489.jpg
# ./refcocog/images/COCO_train2014_000000015582.jpg
# ./refcocog/images/COCO_train2014_000000149381.jpg
# ./refcocog/images/COCO_train2014_000000335824.jpg
# ./refcocog/images/COCO_train2014_000000196922.jpg
# ./refcocog/images/COCO_train2014_000000153561.jpg
# ./refcocog/images/COCO_train2014_000000125585.jpg
# ./refcocog/images/COCO_train2014_000000355223.jpg
# ./refcocog/images/COCO_train2014_000000124795.jpg
# ./refcocog/images/COCO_train2014_000000414838.jpg
# ./refcocog/images/COCO_train2014_000000165232.jpg
# ./refcocog/images/COCO_train2014_000000163362.jpg
# ./refcocog/images/COCO_train2014_000000283448.jpg
# ./refcocog/images/COCO_train2014_000000501085.jpg
# ./refcocog/images/COCO_train2014_000000137808.jpg
# ./refcocog/images/COCO_train2014_000000557860.jpg
# ./refcocog/images/COCO_train2014_000000534906.jpg
# ./refcocog/images/COCO_train2014_000000458586.jpg
# ./refcocog/images/COCO_train2014_000000081508.jpg
# ./refcocog/images/COCO_train2014_000000574087.jpg
# ./refcocog/images/COCO_train2014_000000064463.jpg
# ./refcocog/images/COCO_train2014_000000406767.jpg
# ./refcocog/images/COCO_train2014_000000034837.jpg
# ./refcocog/images/COCO_train2014_000000424370.jpg
# ./refcocog/images/COCO_train2014_000000146236.jpg
# ./refcocog/images/COCO_train2014_000000060145.jpg
# ./refcocog/images/COCO_train2014_000000384027.jpg
# ./refcocog/images/COCO_train2014_000000370479.jpg
# ./refcocog/images/COCO_train2014_000000526754.jpg
# ./refcocog/images/COCO_train2014_000000561308.jpg
# ./refcocog/images/COCO_train2014_000000117455.jpg
# ./refcocog/images/COCO_train2014_000000346566.jpg
# ./refcocog/images/COCO_train2014_000000103846.jpg
# ./refcocog/images/COCO_train2014_000000350044.jpg
# ./refcocog/images/COCO_train2014_000000486005.jpg
# ./refcocog/images/COCO_train2014_000000497296.jpg
# ./refcocog/images/COCO_train2014_000000370748.jpg
# ./refcocog/images/COCO_train2014_000000561495.jpg
# ./refcocog/images/COCO_train2014_000000020012.jpg
# ./refcocog/images/COCO_train2014_000000271930.jpg
# ./refcocog/images/COCO_train2014_000000338248.jpg
# ./refcocog/images/COCO_train2014_000000339549.jpg
# ./refcocog/images/COCO_train2014_000000413037.jpg
# ./refcocog/images/COCO_train2014_000000109588.jpg
# ./refcocog/images/COCO_train2014_000000413277.jpg
# ./refcocog/images/COCO_train2014_000000366489.jpg
# ./refcocog/images/COCO_train2014_000000521881.jpg
# ./refcocog/images/COCO_train2014_000000112126.jpg
# ./refcocog/images/COCO_train2014_000000418385.jpg
# ./refcocog/images/COCO_train2014_000000573640.jpg
# ./refcocog/images/COCO_train2014_000000038027.jpg
# ./refcocog/images/COCO_train2014_000000123462.jpg
# ./refcocog/images/COCO_train2014_000000531151.jpg
# ./refcocog/images/COCO_train2014_000000581282.jpg
# ./refcocog/images/COCO_train2014_000000233193.jpg
# ./refcocog/images/COCO_train2014_000000578231.jpg
# ./refcocog/images/COCO_train2014_000000051512.jpg
# ./refcocog/images/COCO_train2014_000000237474.jpg
# ./refcocog/images/COCO_train2014_000000028131.jpg
# ./refcocog/images/COCO_train2014_000000035322.jpg
# ./refcocog/images/COCO_train2014_000000013283.jpg
# ./refcocog/images/COCO_train2014_000000379115.jpg
# ./refcocog/images/COCO_train2014_000000404964.jpg
# ./refcocog/images/COCO_train2014_000000017866.jpg
# ./refcocog/images/COCO_train2014_000000054437.jpg
# ./refcocog/images/COCO_train2014_000000053533.jpg
# ./refcocog/images/COCO_train2014_000000264752.jpg
# ./refcocog/images/COCO_train2014_000000557105.jpg
# ./refcocog/images/COCO_train2014_000000361811.jpg
# ./refcocog/images/COCO_train2014_000000400285.jpg
# ./refcocog/images/COCO_train2014_000000415280.jpg
# ./refcocog/images/COCO_train2014_000000340244.jpg
# ./refcocog/images/COCO_train2014_000000467872.jpg
# ./refcocog/images/COCO_train2014_000000561713.jpg
# ./refcocog/images/COCO_train2014_000000136700.jpg
# ./refcocog/images/COCO_train2014_000000291347.jpg
# ./refcocog/images/COCO_train2014_000000079642.jpg
# ./refcocog/images/COCO_train2014_000000479763.jpg
# ./refcocog/images/COCO_train2014_000000362301.jpg
# ./refcocog/images/COCO_train2014_000000254218.jpg
# ./refcocog/images/COCO_train2014_000000102166.jpg
# ./refcocog/images/COCO_train2014_000000268388.jpg
# ./refcocog/images/COCO_train2014_000000205272.jpg
# ./refcocog/images/COCO_train2014_000000509864.jpg
# ./refcocog/images/COCO_train2014_000000271077.jpg
# ./refcocog/images/COCO_train2014_000000033642.jpg
# ./refcocog/images/COCO_train2014_000000569062.jpg
# ./refcocog/images/COCO_train2014_000000313570.jpg
# ./refcocog/images/COCO_train2014_000000108617.jpg
# ./refcocog/images/COCO_train2014_000000008816.jpg
# ./refcocog/images/COCO_train2014_000000494618.jpg
# ./refcocog/images/COCO_train2014_000000529542.jpg
# ./refcocog/images/COCO_train2014_000000395409.jpg
# ./refcocog/images/COCO_train2014_000000079572.jpg
# ./refcocog/images/COCO_train2014_000000126994.jpg
# ./refcocog/images/COCO_train2014_000000199251.jpg
# ./refcocog/images/COCO_train2014_000000490508.jpg
# ./refcocog/images/COCO_train2014_000000534559.jpg
# ./refcocog/images/COCO_train2014_000000551279.jpg
# ./refcocog/images/COCO_train2014_000000250579.jpg
# ./refcocog/images/COCO_train2014_000000131030.jpg
# ./refcocog/images/COCO_train2014_000000516624.jpg
# ./refcocog/images/COCO_train2014_000000093356.jpg
# ./refcocog/images/COCO_train2014_000000311821.jpg
# ./refcocog/images/COCO_train2014_000000387349.jpg
# ./refcocog/images/COCO_train2014_000000455300.jpg
# ./refcocog/images/COCO_train2014_000000380729.jpg
# ./refcocog/images/COCO_train2014_000000282042.jpg
# ./refcocog/images/COCO_train2014_000000447999.jpg
# ./refcocog/images/COCO_train2014_000000340038.jpg
# ./refcocog/images/COCO_train2014_000000278469.jpg
# ./refcocog/images/COCO_train2014_000000015518.jpg
# ./refcocog/images/COCO_train2014_000000226455.jpg
# ./refcocog/images/COCO_train2014_000000459723.jpg
# ./refcocog/images/COCO_train2014_000000431492.jpg
# ./refcocog/images/COCO_train2014_000000522968.jpg
# ./refcocog/images/COCO_train2014_000000570338.jpg
# ./refcocog/images/COCO_train2014_000000302227.jpg
# ./refcocog/images/COCO_train2014_000000262549.jpg
# ./refcocog/images/COCO_train2014_000000534521.jpg
# ./refcocog/images/COCO_train2014_000000343385.jpg
# ./refcocog/images/COCO_train2014_000000280450.jpg
# ./refcocog/images/COCO_train2014_000000209027.jpg
# ./refcocog/images/COCO_train2014_000000553366.jpg
# ./refcocog/images/COCO_train2014_000000147597.jpg
# ./refcocog/images/COCO_train2014_000000570351.jpg
# ./refcocog/images/COCO_train2014_000000366643.jpg
# ./refcocog/images/COCO_train2014_000000252492.jpg
# ./refcocog/images/COCO_train2014_000000478164.jpg
# ./refcocog/images/COCO_train2014_000000436214.jpg
# ./refcocog/images/COCO_train2014_000000184610.jpg
# ./refcocog/images/COCO_train2014_000000490490.jpg
# ./refcocog/images/COCO_train2014_000000104502.jpg
# ./refcocog/images/COCO_train2014_000000100859.jpg
# ./refcocog/images/COCO_train2014_000000447476.jpg
# ./refcocog/images/COCO_train2014_000000106001.jpg
# ./refcocog/images/COCO_train2014_000000292537.jpg
# ./refcocog/images/COCO_train2014_000000188902.jpg
# ./refcocog/images/COCO_train2014_000000474637.jpg
# ./refcocog/images/COCO_train2014_000000398850.jpg
# ./refcocog/images/COCO_train2014_000000425670.jpg
# ./refcocog/images/COCO_train2014_000000138069.jpg
# ./refcocog/images/COCO_train2014_000000044277.jpg
# ./refcocog/images/COCO_train2014_000000060903.jpg
# ./refcocog/images/COCO_train2014_000000334777.jpg
# ./refcocog/images/COCO_train2014_000000161924.jpg
# ./refcocog/images/COCO_train2014_000000152600.jpg
# ./refcocog/images/COCO_train2014_000000309257.jpg
# ./refcocog/images/COCO_train2014_000000397276.jpg
# ./refcocog/images/COCO_train2014_000000044816.jpg
# ./refcocog/images/COCO_train2014_000000214008.jpg
# ./refcocog/images/COCO_train2014_000000094884.jpg
# ./refcocog/images/COCO_train2014_000000272282.jpg
# ./refcocog/images/COCO_train2014_000000204431.jpg
# ./refcocog/images/COCO_train2014_000000323478.jpg
# ./refcocog/images/COCO_train2014_000000070059.jpg
# ./refcocog/images/COCO_train2014_000000130270.jpg
# ./refcocog/images/COCO_train2014_000000177467.jpg
# ./refcocog/images/COCO_train2014_000000485913.jpg
# ./refcocog/images/COCO_train2014_000000428379.jpg
# ./refcocog/images/COCO_train2014_000000111148.jpg
# ./refcocog/images/COCO_train2014_000000306094.jpg
# ./refcocog/images/COCO_train2014_000000177748.jpg
# ./refcocog/images/COCO_train2014_000000522234.jpg
# ./refcocog/images/COCO_train2014_000000085659.jpg
# ./refcocog/images/COCO_train2014_000000076654.jpg
# ./refcocog/images/COCO_train2014_000000461560.jpg
# ./refcocog/images/COCO_train2014_000000366560.jpg
# ./refcocog/images/COCO_train2014_000000275372.jpg
# ./refcocog/images/COCO_train2014_000000391439.jpg
# ./refcocog/images/COCO_train2014_000000194974.jpg
# ./refcocog/images/COCO_train2014_000000054903.jpg
# ./refcocog/images/COCO_train2014_000000261316.jpg
# ./refcocog/images/COCO_train2014_000000484418.jpg
# ./refcocog/images/COCO_train2014_000000163727.jpg
# ./refcocog/images/COCO_train2014_000000117059.jpg
# ./refcocog/images/COCO_train2014_000000514846.jpg
# ./refcocog/images/COCO_train2014_000000448013.jpg
# ./refcocog/images/COCO_train2014_000000317684.jpg
# ./refcocog/images/COCO_train2014_000000466530.jpg
# ./refcocog/images/COCO_train2014_000000410190.jpg
# ./refcocog/images/COCO_train2014_000000301232.jpg
# ./refcocog/images/COCO_train2014_000000235905.jpg
# ./refcocog/images/COCO_train2014_000000199427.jpg
# ./refcocog/images/COCO_train2014_000000179278.jpg
# ./refcocog/images/COCO_train2014_000000417573.jpg
# ./refcocog/images/COCO_train2014_000000135459.jpg
# ./refcocog/images/COCO_train2014_000000127214.jpg
# ./refcocog/images/COCO_train2014_000000565387.jpg
# ./refcocog/images/COCO_train2014_000000327936.jpg
# ./refcocog/images/COCO_train2014_000000089072.jpg
# ./refcocog/images/COCO_train2014_000000012501.jpg
# ./refcocog/images/COCO_train2014_000000156895.jpg
# ./refcocog/images/COCO_train2014_000000199408.jpg
# ./refcocog/images/COCO_train2014_000000561186.jpg
# ./refcocog/images/COCO_train2014_000000301657.jpg
# ./refcocog/images/COCO_train2014_000000164727.jpg
# ./refcocog/images/COCO_train2014_000000270323.jpg
# ./refcocog/images/COCO_train2014_000000416811.jpg
# ./refcocog/images/COCO_train2014_000000204705.jpg
# ./refcocog/images/COCO_train2014_000000560581.jpg
# ./refcocog/images/COCO_train2014_000000093666.jpg
# ./refcocog/images/COCO_train2014_000000110704.jpg
# ./refcocog/images/COCO_train2014_000000178112.jpg
# ./refcocog/images/COCO_train2014_000000218492.jpg

# %% [markdown]
# ## Accessing an image from the unzipped dataset with Pillow

# %%
img_color = Image.open('dataset/refcocog/images/COCO_train2014_000000380440.jpg')
img_color.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x376 at 0x7FB2FF7F8B20>

# %% [markdown]
# ## Using pickle in order to open .p files with text and positions of boxes

# %%
import pandas as pd

# Change folder name because parenthesis in filename cause problems opening it

annotations = pd.read_pickle("dataset/refcocog/annotations/refs_umd.p")
print(annotations[0])
# Out:
# {'image_id': 380440, 'split': 'test', 'sentences': [{'tokens': ['the', 'man', 'in', 'yellow', 'coat'], 'raw': 'the man in yellow coat', 'sent_id': 8, 'sent': 'the man in yellow coat'}, {'tokens': ['skiier', 'in', 'red', 'pants'], 'raw': 'Skiier in red pants.', 'sent_id': 9, 'sent': 'skiier in red pants'}], 'file_name': 'COCO_train2014_000000380440_491042.jpg', 'category_id': 1, 'ann_id': 491042, 'sent_ids': [8, 9], 'ref_id': 0}

# %% [markdown]
# ## Accessing the boxes annotations in the .json file

# %%
import json 
# Opening JSON file
f = open('dataset/refcocog/annotations/instances.json')
  
# returns JSON object as 
# a dictionary
boxes_data = json.load(f)
boxes_data_fmt = json.dumps(boxes_data, indent=2)

# %% [markdown]
# ### The dictionary has 5 keys: info, images, licenses, annotations, categories
#
# *   Annotations keep a reference to the image, and the bounding box coordinates
# *   Images keeps the image filename

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Closing the JSON file!!

# %%
f.close()

# %% [markdown]
# ## Tree view of the data

# %%
#plotting all the informations about the dataset
print("#########  dataset/refcocog/annotations/refs_umd.p  #########\n")
print(f"annotations lenght: {len(annotations)}")
print(f"annotations type: {type(annotations)}\n")
print(f"\telement of annotations type: {type(annotations[0])}")
print(f"\telement of annotations: {annotations[0]}")
print(f"\tkeys: {annotations[0].keys()}\n")
print(f"\t\timage_id type: {type(annotations[0]['image_id'])}")
print(f"\t\tsplit type: {type(annotations[0]['split'])}")
print(f"\t\tsentences type: {type(annotations[0]['sentences'])}\n")
print(f"\t\t\telement of sentences type: {type(annotations[0]['sentences'][0])}")
print(f"\t\t\telement of sentences: {annotations[0]['sentences'][0]}")
print(f"\t\t\tkeys: {annotations[0]['sentences'][0].keys()}\n")
print(f"\t\t\t\ttokens type: {type(annotations[0]['sentences'][0]['tokens'])}")
print(f"\t\t\t\traw type: {type(annotations[0]['sentences'][0]['raw'])}")
print(f"\t\t\t\tsent_id type: {type(annotations[0]['sentences'][0]['sent_id'])}")
print(f"\t\t\t\tsent type: {type(annotations[0]['sentences'][0]['sent'])}\n")
print(f"\t\tfile_name type: {type(annotations[0]['file_name'])}")
print(f"\t\tcategory_id type: {type(annotations[0]['category_id'])}")
print(f"\t\tann_id type: {type(annotations[0]['ann_id'])}")
print(f"\t\tsent_ids type: {type(annotations[0]['sent_ids'])}\n")
print(f"\t\t\telement of sent_ids type: {type(annotations[0]['sent_ids'][0])}")
print(f"\t\t\telement of sent_ids: {annotations[0]['sent_ids'][0]}\n")
print(f"\t\tref_id type: {type(annotations[0]['ref_id'])}\n")

print("#########  dataset/refcocog/annotations/instances.json  #########\n")
print(f"boxes type: {type(boxes_data)}")
print(f"boxes: {boxes_data.keys()}\n")
print(f"\tinfo type: {type(boxes_data['info'])}")
print(f"\timages type: {type(boxes_data['images'])}")
print(f"\tlicenses type: {type(boxes_data['licenses'])}")
print(f"\tannotations type: {type(boxes_data['annotations'])}\n")
print(f"\t\telement of annotations type: {type(boxes_data['annotations'][0])}")
print(f"\t\telement of annotations: {boxes_data['annotations'][0]}")
print(f"\t\tkeys: {boxes_data['annotations'][0].keys()}\n")
print(f"\t\t\tsegmentation type: {type(boxes_data['annotations'][0]['segmentation'])}")
print(f"\t\t\tarea type: {type(boxes_data['annotations'][0]['area'])}")
print(f"\t\t\tiscrowd type: {type(boxes_data['annotations'][0]['iscrowd'])}")
print(f"\t\t\timage_id type: {type(boxes_data['annotations'][0]['image_id'])}")
print(f"\t\t\tbbox type: {type(boxes_data['annotations'][0]['bbox'])}\n")
print(f"\t\t\t\texample bbox: {boxes_data['annotations'][0]['bbox']}\n")
print(f"\t\t\tcategory_id type: {type(boxes_data['annotations'][0]['category_id'])}")
print(f"\t\t\tid type: {type(boxes_data['annotations'][0]['id'])}\n")
print(f"\tcategories type: {type(boxes_data['categories'])}\n")
print(f"\t\telement of categories type: {type(boxes_data['categories'][0])}")
print(f"\t\telement of categories: {boxes_data['categories'][0]}")
print(f"\t\tkeys: {boxes_data['categories'][0].keys()}")
# Out:
# #########  dataset/refcocog/annotations/refs_umd.p  #########
#
# annotations lenght: 49822
# annotations type: <class 'list'>
#
# 	element of annotations type: <class 'dict'>
# 	element of annotations: {'image_id': 380440, 'split': 'test', 'sentences': [{'tokens': ['the', 'man', 'in', 'yellow', 'coat'], 'raw': 'the man in yellow coat', 'sent_id': 8, 'sent': 'the man in yellow coat'}, {'tokens': ['skiier', 'in', 'red', 'pants'], 'raw': 'Skiier in red pants.', 'sent_id': 9, 'sent': 'skiier in red pants'}], 'file_name': 'COCO_train2014_000000380440_491042.jpg', 'category_id': 1, 'ann_id': 491042, 'sent_ids': [8, 9], 'ref_id': 0}
# 	keys: dict_keys(['image_id', 'split', 'sentences', 'file_name', 'category_id', 'ann_id', 'sent_ids', 'ref_id'])
#
# 		image_id type: <class 'int'>
# 		split type: <class 'str'>
# 		sentences type: <class 'list'>
#
# 			element of sentences type: <class 'dict'>
# 			element of sentences: {'tokens': ['the', 'man', 'in', 'yellow', 'coat'], 'raw': 'the man in yellow coat', 'sent_id': 8, 'sent': 'the man in yellow coat'}
# 			keys: dict_keys(['tokens', 'raw', 'sent_id', 'sent'])
#
# 				tokens type: <class 'list'>
# 				raw type: <class 'str'>
# 				sent_id type: <class 'int'>
# 				sent type: <class 'str'>
#
# 		file_name type: <class 'str'>
# 		category_id type: <class 'int'>
# 		ann_id type: <class 'int'>
# 		sent_ids type: <class 'list'>
#
# 			element of sent_ids type: <class 'int'>
# 			element of sent_ids: 8
#
# 		ref_id type: <class 'int'>
#
# #########  dataset/refcocog/annotations/instances.json  #########
#
# boxes type: <class 'dict'>
# boxes: dict_keys(['info', 'images', 'licenses', 'annotations', 'categories'])
#
# 	info type: <class 'dict'>
# 	images type: <class 'list'>
# 	licenses type: <class 'list'>
# 	annotations type: <class 'list'>
#
# 		element of annotations type: <class 'dict'>
# 		element of annotations: {'segmentation': [[21.11, 239.09, 16.31, 274.6, 198.65, 349.45, 240.87, 336.98, 320.52, 293.79, 334.91, 248.69, 357.95, 273.64, 353.15, 289.0, 398.25, 267.88, 437.6, 251.57, 412.65, 228.54, 240.87, 210.31, 219.76, 141.21, 113.24, 153.69, 63.34, 156.57, 26.87, 169.04]], 'area': 48667.84089999999, 'iscrowd': 0, 'image_id': 131074, 'bbox': [16.31, 141.21, 421.29, 208.24], 'category_id': 65, 'id': 318235}
# 		keys: dict_keys(['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id'])
#
# 			segmentation type: <class 'list'>
# 			area type: <class 'float'>
# 			iscrowd type: <class 'int'>
# 			image_id type: <class 'int'>
# 			bbox type: <class 'list'>
#
# 				example bbox: [16.31, 141.21, 421.29, 208.24]
#
# 			category_id type: <class 'int'>
# 			id type: <class 'int'>
#
# 	categories type: <class 'list'>
#
# 		element of categories type: <class 'dict'>
# 		element of categories: {'supercategory': 'person', 'id': 1, 'name': 'person'}
# 		keys: dict_keys(['supercategory', 'id', 'name'])

# %% [markdown]
# # Params/Hyperparams/Constants

# %%
BATCH_SIZE = 128
RANDOM_INDEX_IMAGE = 110
IMAGES_DIR = 'dataset/refcocog/images/'

# %% [markdown]
# # Dataclass creation

# %% [markdown]
# ## Dataclass creation
# The dataclass contains a structure such as:
# * A map with image_id's as key
# * For every image Id, the value is a list
# * Each element of such list is a map of informations regarding bboxes and relative annotations (if any, otherwise None)
# * DataLoader is still to be done

# %% [markdown]
# ## Dict dataclass (For DataLoader purposes)
# * Create a map of lists
# * The keys of the map are the fields of the dataset we are interested into
# * The record in each list must be ordered (index 0 in 'filename' list must correspond to index 0 in 'annotation' list

# %%
from torch.utils.data import Dataset, DataLoader
import random

class VGDataset(Dataset):
  def __init__(self, boxes_data : dict, annotations : list[dict], mode = 'annotated', split = 'train'):
    self.mode = mode
    self.split = split
    self.data = self.create_structure(boxes_data, annotations)
    self.clean_data = self.create_clean_structure(boxes_data, annotations)
    self.n = len(self.get_data_structure()['filename'])

    #Creates structure that is suitable for dataloader
  def create_structure(self, boxes_data, annotations):
    data = {}
    data['filename'] = []
    data['annotation'] = []
    data['box'] = []

    # Turn list of dictionaries into dictionary of list of dictionary FOR ANNOTATIONS i.e. the description text
    annotations_dict = {}
    for item in annotations:
      name = item['image_id']
      if name not in annotations_dict.keys():
        annotations_dict[name] = []
      annotations_dict[name].append(item)

    # Turn list of dictionaries into dictionary of list of dictionary FOR BOXES_ANNOTATIONS
    boxes_dict = {}
    for item in boxes_data['annotations']:
      name = item['image_id']
      if name not in boxes_dict.keys():
        boxes_dict[name] = []
      boxes_dict[name].append(item)

    # Turn list of dictionaries into dictionary of dictionary FOR BOXES_IMAGES (needed for filename)
    # Path of the image
    boxes_img_dict = {}
    for item in boxes_data['images']:
      name = item['id']
      boxes_img_dict[name] = item

    #Build the overall dataset, comprised of img id, box and annotation corresponding to the box (if there is one), and filename (similar to id but not same)
    for image_id in boxes_dict.keys():
      tmp_dict = {}
      for box in boxes_dict[image_id]:
        annotation_id = box['id']
        tmp_dict['box'] = box
        found = False
        for annotation in annotations_dict[image_id]:
          if annotation['ann_id'] == annotation_id:
            found = True
            tmp_dict['annotation'] = annotation

        if not found:
          tmp_dict['annotation'] = None

        #Getting filename from boxes_data['Images']
        tmp_dict['filename'] = IMAGES_DIR+boxes_img_dict[image_id]['file_name']

        data['filename'].append(tmp_dict['filename'])
        data['annotation'].append(tmp_dict['annotation'])
        data['box'].append(tmp_dict['box'])

    return data



#Creates structure that is suitable for dataloader
  def create_clean_structure(self, boxes_data, annotations):
    data = {}
    data['filename'] = []
    data['annotation'] = []
    data['box'] = []

    # Turn list of dictionaries into dictionary of list of dictionary FOR ANNOTATIONS i.e. the description text
    annotations_dict = {}
    for item in annotations:
      name = item['image_id']
      if name not in annotations_dict.keys():
        annotations_dict[name] = []
      annotations_dict[name].append(item)

    # Turn list of dictionaries into dictionary of list of dictionary FOR BOXES_ANNOTATIONS
    boxes_dict = {}
    for item in boxes_data['annotations']:
      name = item['image_id']
      if name not in boxes_dict.keys():
        boxes_dict[name] = []
      boxes_dict[name].append(item)

    # Turn list of dictionaries into dictionary of dictionary FOR BOXES_IMAGES (needed for filename)
    # Path of the image
    boxes_img_dict = {}
    for item in boxes_data['images']:
      name = item['id']
      boxes_img_dict[name] = item

    #Build the overall dataset, comprised of img id, box and annotation corresponding to the box (if there is one), and filename (similar to id but not same)
    for image_id in boxes_dict.keys():
      tmp_dict = {}
      for box in boxes_dict[image_id]:
        annotation_id = box['id']
        tmp_dict['box'] = box
        found = False
        for annotation in annotations_dict[image_id]:
          if annotation['ann_id'] == annotation_id:
            if annotation['split'] == self.split:
              found = True
              tmp_dict['annotation'] = annotation

        if not found:
          tmp_dict['annotation'] = None
          continue

        #Getting filename from boxes_data['Images']
        tmp_dict['filename'] = IMAGES_DIR+boxes_img_dict[image_id]['file_name']

        data['filename'].append(tmp_dict['filename'])
        data['annotation'].append(tmp_dict['annotation'])
        data['box'].append(tmp_dict['box'])

        assert len(data['filename']) == len(data['annotation']) == len(data['box']), 'Data inconsistency'
    return data


#Returns data structure to use in the functions
  def get_data_structure(self):
    if self.mode == 'annotated':
      data_structure = self.clean_data
    elif self.mode == 'any':
      data_structure = self.data
    
    return data_structure

  #Get item for the dataloader
  def __getitem__(self, index):
    data_structure = self.get_data_structure()
    filename = data_structure['filename'][index]
    annotation = data_structure['annotation'][index]['sentences'][0]['raw']
    bbox = data_structure['box'][index]['bbox']
    return filename, annotation, torch.Tensor(bbox)

  #Get length of 
  def __len__(self):
    return self.n

# %% [markdown]
# ### Instantiation of dict dataclass

# %%
train_data = VGDataset(boxes_data, annotations, 'annotated', 'train')
test_data = VGDataset(boxes_data, annotations, 'annotated', 'test')
val_data = VGDataset(boxes_data, annotations, 'annotated', 'val')

print(f"""
Len train: {len(train_data)}
Len test: {len(test_data)}
Len val: {len(val_data)}
""")

train_loader = torch.utils.data.DataLoader(train_data, BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, BATCH_SIZE, shuffle=True)

for batch_idx, (filenames, anns, bboxes) in enumerate(test_loader):
  for i,(filename, annotation, bbox) in tqdm(enumerate(zip(filenames, anns, bboxes))):
    #BIG ISSUE; DATA LOADER EXTRACTS BOUNDING BOXES IN A BAD WAY
    ...

# %% [markdown]
# ## List Dataclass (TO BE CANCELED IF EVERYTHING ELSE WORKS)
# * Instead of a map of lists of maps of maps i want to do a basic list of maps
# * One with the None annotations, another other without

# %%
from torch.utils.data import Dataset, DataLoader
import random

class VGDataset_list(Dataset):
  #Mode could be 'annotated' or 'any'
  def __init__(self, boxes_data, annotations, mode = 'annotated'):
    self.mode = mode
    self.data = self.create_list(boxes_data, annotations)
    self.clean_data = self.create_clean_list(boxes_data, annotations)
    self.train_indx, self.test_indx, self.val_indx = self.get_data(BATCH_SIZE)

#Creates the data structure including all the records, even the ones with no annotation
  def create_list(self, boxes_data, annotations):
    data = []
    
    # Turn list of dictionaries into dictionary of list of dictionary FOR ANNOTATIONS i.e. the description text
    annotations_dict = {}
    for item in annotations:
      name = item['image_id']
      if name not in annotations_dict.keys():
        annotations_dict[name] = []
      annotations_dict[name].append(item)

    #print('annotation ', annotations_dict[127])
    
    # Turn list of dictionaries into dictionary of list of dictionary FOR BOXES_ANNOTATIONS
    boxes_dict = {}
    for item in boxes_data['annotations']:
      name = item['image_id']
      if name not in boxes_dict.keys():
        boxes_dict[name] = []
      boxes_dict[name].append(item)

    #print('boxes ', boxes_dict[127])

    # Turn list of dictionaries into dictionary of dictionary FOR BOXES_IMAGES (needed for filename)
    # Path of the image
    boxes_img_dict = {}
    for item in boxes_data['images']:
      name = item['id']
      boxes_img_dict[name] = item

    #Build the overall dataset, comprised of img id, box and annotation corresponding to the box (if there is one), and filename (similar to id but not same)
    for image_id in boxes_dict.keys():
      tmp_dict = {}
      for box in boxes_dict[image_id]:
        annotation_id = box['id']
        tmp_dict['box'] = box
        found = False
        for annotation in annotations_dict[image_id]:
          if annotation['ann_id'] == annotation_id:
            found = True
            tmp_dict['annotation'] = annotation

        if not found:
          tmp_dict['annotation'] = None

        #Getting filename from boxes_data['Images']
        tmp_dict['filename'] = IMAGES_DIR+boxes_img_dict[image_id]['file_name']
        data.append(tmp_dict.copy())
    return data



#Creates the data structure including only records with relative annotation
  def create_clean_list(self, boxes_data, annotations):
    data = []
    
    # Turn list of dictionaries into dictionary of list of dictionary FOR ANNOTATIONS i.e. the description text
    annotations_dict = {}
    for item in annotations:
      name = item['image_id']
      if name not in annotations_dict.keys():
        annotations_dict[name] = []
      annotations_dict[name].append(item)

    #print('annotation ', annotations_dict[127])
    
    # Turn list of dictionaries into dictionary of list of dictionary FOR BOXES_ANNOTATIONS
    boxes_dict = {}
    for item in boxes_data['annotations']:
      name = item['image_id']
      if name not in boxes_dict.keys():
        boxes_dict[name] = []
      boxes_dict[name].append(item)

    #print('boxes ', boxes_dict[127])

    # Turn list of dictionaries into dictionary of dictionary FOR BOXES_IMAGES (needed for filename)
    # Path of the image
    boxes_img_dict = {}
    for item in boxes_data['images']:
      name = item['id']
      boxes_img_dict[name] = item

    #Build the overall dataset, comprised of img id, box and annotation corresponding to the box (if there is one), and filename (similar to id but not same)
    for image_id in boxes_dict.keys():
      tmp_dict = {}
      for box in boxes_dict[image_id]:
        annotation_id = box['id']
        tmp_dict['box'] = box
        found = False
        for annotation in annotations_dict[image_id]:
          if annotation['ann_id'] == annotation_id:
            found = True
            tmp_dict['annotation'] = annotation

        if not found:
          tmp_dict['annotation'] = None
          continue

        #Getting filename from boxes_data['Images']
        tmp_dict['filename'] = IMAGES_DIR+boxes_img_dict[image_id]['file_name']
        data.append(tmp_dict.copy())
    return data




#Returns data structure to use in the functions
  def get_data_structure(self):
    if self.mode == 'annotated':
      data_structure = self.clean_data
    elif self.mode == 'any':
      data_structure = self.data
    
    return data_structure

#Creates the dataloaders (needs modification)
  def get_data(self, batch_size):
    data_structure = self.get_data_structure()
    # initialize dataloaders
    train = []
    test = []
    val = []
    contrastive_train = []

    for index,item in enumerate(data_structure):
        if item['annotation'] == None:
          contrastive_train.append(index)
        elif item['annotation']['split'] == 'train':
          train.append(item)
        elif item['annotation']['split'] == 'test':
          test.append(item)
        elif item['annotation']['split'] == 'val':
          val.append(item)
        else:
          print('should not print')

    train_loader = torch.utils.data.DataLoader(train, batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val, batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test, batch_size, shuffle=False)
      
    return train_loader, test_loader, val_loader



#Base methods
  def __getitem__(self, index):
      data_structure = self.get_data_structure()
      return data_structure[index]


  def __len__(self):
      data_structure = self.get_data_structure()
      return len(data_structure)
    
#Other methods for getting data

  def get_list_by_filename(self, filename):

    data_structure = self.get_data_structure()

    annotated_list = []

    for record in self.data_structure:
      if record['filename'] == filename:
        annotated_list.append(record)
    return annotated_list

  def get_rnd_item_by_filename(self, filename):

    item_list = self.get_list_by_filename(filename)
    index = random.randint(0, len(item_list)-1)
    return item_list[index]

# %% [markdown]
# ### Instantiation of alternative dataclass

# %%
print(annotations)
data_list = VGDataset_list(boxes_data, annotations, 'annotated')
print(f"Length of list dataset with junk: {len(data_list.data)}")
print(f"Length of list dataset without none annotations {len(data_list.clean_data)}")
print(f"Length of train samples {data_list.train_indx.batch_size}")
print(f"Length of test samples {data_list.test_indx.batch_size}")
print(f"Length of validation samples {data_list.val_indx.batch_size}")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Length of list dataset with junk: 208960
# Length of list dataset without none annotations 49820
# Length of train samples 128
# Length of test samples 128
# Length of validation samples 128

# %% [markdown]
# # YOLO

# %% [markdown]
# ## Installing YOLO

# %%
# !pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

#Loading the small model
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
#yolo_model.names
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-4-28 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# ## Computing Bboxes with YOLO
# With YOLO, we can pass an image in order to get the classes of objects inside that image.
#
# There are 80 classes in YOLO.

# %%
#Batch of images (a single one in this example)
image_str = [data_list[RANDOM_INDEX_IMAGE]['filename']]


#Using YOLO
results = yolo_model(image_str)
numpy_results = results.xyxy[0].detach().cpu().numpy()
results.print()
results.pandas().xyxy[0]
# Out:
# image 1/1: 467x640 3 zebras
# Speed: 12.7ms pre-process, 9.6ms inference, 1.6ms NMS per image at shape (1, 3, 480, 640)
#          xmin        ymin        xmax        ymax  confidence  class   name
# 0    0.000000  153.464539  107.130966  283.854584    0.827658     22  zebra
# 1  215.728622  181.306396  505.294434  377.747681    0.733714     22  zebra
# 2  121.154037  203.156174  169.347183  277.561035    0.327525     22  zebra

# %% [markdown]
# ## Visualizing Yolo's bounding boxes

# %%
#bbox in form of list of coordinates [xmin, ymin, xmax, ymax]
def make_bbox(image, bbox):
  coords = [(bbox[0], bbox[1]), (bbox[2], bbox[3])]
  bounded_image = ImageDraw.Draw(image)
  bounded_image.rectangle(coords, outline = 'red')
  return image

# %%
YOLO_INDEX = 0
image = Image.open(data_list[RANDOM_INDEX_IMAGE]['filename'])
bbox =  [numpy_results[YOLO_INDEX][0], numpy_results[YOLO_INDEX][1], numpy_results[YOLO_INDEX][2], numpy_results[YOLO_INDEX][3]]
make_bbox(image , bbox)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x467 at 0x7FB2991C0310>

# %% [markdown]
# # CLIP

# %% [markdown]
# ## Installation

# %%
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-m3q9zokc
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-m3q9zokc
#   Resolved https://github.com/openai/CLIP.git to commit a9b1bf5920416aaeaec965c25dd9e8f98c864f16
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.65.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.15.1+cu118)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.5.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->clip==1.0) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->clip==1.0) (3.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)

# %% [markdown]
# ## Info about CLIP model

# %%
import clip
import numpy as np
print(f"Available models: {clip.available_models()}")
# Choosing RN50 following assignemt constraint:
# "Unless justified by design choices, you are constrained to use the ResNet50 version of CLIP"

device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
#preprocess is transform
clip_model, preprocess = clip.load('RN50')
if device == 'cuda':
  clip_model.cuda().eval()
input_resolution = clip_model.visual.input_resolution
context_length = clip_model.context_length
vocab_size = clip_model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in clip_model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Available models: ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']
# cuda
# Model parameters: 102,007,137
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %% [markdown]
# ## Evaluating bounding boxes with CLIP: IDEA
# * Cropping the bounding boxes predicted by YOLO
# * preprocessing of an image annotation
# * preprocessing of cropped images
# * compute cosine similarity between the encoding of each image and the encoding of the annotation

# %% [markdown]
# ### Evaluation: Cosine similarity

# %%
from torch.nn.common_types import Tensor
#Takes two tensors as input
def compute_cos_sim(image_feature_matrix : Tensor, annotation_encoding : Tensor):
  #Normalization step
  annotation_encoding /= annotation_encoding.norm(dim=-1, keepdim=True)
  image_feature_matrix /= image_feature_matrix.norm(dim=-1, keepdim=True)

  #Computing the similarity
  similarity=((100.0 * annotation_encoding @ image_feature_matrix.T).softmax(dim=-1))
  values, indices = similarity[0].topk(1)

  return indices[0]

# %% [markdown]
# ### Evaluation: Intersection over Union

# %%
def compute_IoU(predicted_bbox : list, gold_bbox: list ):
  """ We assume that the box follows the format:
		box1 = [x1,y1,x2,y2], and box2 = [x3,y3,x4,y4],
		where (x1,y1) and (x3,y3) represent the top left coordinate,
		and (x2,y2) and (x4,y4) represent the bottom right coordinate """
  #
  #It is working now, but
  #The computed area of the gold_bbox is different with respect to
  #the one present in the dataset
  #I've seen this only in 1/1 photo, maybe it is a dataset problem, idk
  #
  #Is it symmetric? YES IT IS
  x1, y1, x2, y2 = predicted_bbox	
  x3, y3, x4, y4 = gold_bbox
  x_inter1 = max(x1, x3)
  y_inter1 = max(y1, y3)
  x_inter2 = min(x2, x4)
  y_inter2 = min(y2, y4)
  area_inter = abs(max((x_inter2 - x_inter1, 0)) * max((y_inter2 - y_inter1), 0))
  width_box1 = abs(x2 - x1)
  height_box1 = abs(y2 - y1)
  width_box2 = abs(x4 - x3)
  height_box2 = abs(y4 - y3)
  area_box1 = width_box1 * height_box1
  area_box2 = width_box2 * height_box2
  area_union = area_box1 + area_box2 - area_inter
  iou = area_inter / area_union
  return iou

# %% [markdown]
# ### Evaluation: Recall

# %% [markdown]
# ### Computing cosine similarity between the cropped images and the gold annotation

# %%
#bbox and annotation to be used from now on
element = data_list[RANDOM_INDEX_IMAGE]

# %%
def show_cropped_images(cropped_images):
  for i in range(len(cropped_images)):
    cropped_images[i].show()

# %%
image = Image.open(data_list[RANDOM_INDEX_IMAGE]['filename'])
cropped_images = []

for bbox in numpy_results:
  cropped_images.append(image.crop((bbox[0], bbox[1], bbox[2], bbox[3])))


# Annotation of the desired bounding box (cropped image)
# !!!
# WATCH OUT: We are currently getting a random annotation
# The accuracy result is replicable ONLY IF there is one annotation for the img
# !!!
# NOTE: the accuracy is to be computed over a batch of the dataset (taking the average for example)
annotation_element = element['annotation']
raw_sentence = annotation_element['sentences'][0]['raw']
print(f"Sentence obtained from image with index {RANDOM_INDEX_IMAGE}: {raw_sentence}")

# Text encoding
text_inputs = torch.cat([clip.tokenize(raw_sentence)]).to(device)
# Clip Embedding dimension for text input (RESNET50) -> text_features.shape == 1024
with torch.no_grad():
    text_features = clip_model.encode_text(text_inputs)




# Images encoding
images_features = []
for img in cropped_images:
  image_input = preprocess(img).unsqueeze(0).to(device)
  # Clip Embedding dimension for image input (RESNET50) -> image_features.shape == 1024
  with torch.no_grad():
    images_features.append(clip_model.encode_image(image_input.detach().clone()))

show_cropped_images(cropped_images)

#Bringing list of images into a tensor
tensor_images_features = torch.stack(images_features).squeeze(1)

#Computing cosine similarity
best_bbox_indx = compute_cos_sim(tensor_images_features, text_features)
# Out:
# Sentence obtained from image with index 110: A zebra with a metal beam obstructing our view of it.
# <PIL.Image.Image image mode=RGB size=107x131 at 0x7FB2FF7DC760>
# <PIL.Image.Image image mode=RGB size=289x197 at 0x7FB2FF7DF940>
# <PIL.Image.Image image mode=RGB size=48x75 at 0x7FB2FF7DFEE0>

# %% [markdown]
# ### Computing Intersection over Union (IoU)

# %%
#Recollect bounding box on best crop from index
predicted_bbox = [numpy_results[best_bbox_indx][0], numpy_results[best_bbox_indx][1], numpy_results[best_bbox_indx][2], numpy_results[best_bbox_indx][3]]

#Extract gold bbox
box = element['box']
bbox = box['bbox']
gold_bbox = [bbox[0], bbox[1], bbox[0]+bbox[2], bbox[1]+bbox[3]]

#Compute intersection over union
iou = compute_IoU(predicted_bbox, gold_bbox)


print(f"Gold bbox: {gold_bbox} and predicted bbox: {predicted_bbox}")
print(f"The IoU value is {iou}")
# Out:
# Gold bbox: [0.0, 156.64, 170.42, 283.46999999999997] and predicted bbox: [0.0, 153.46454, 107.13097, 283.85458]
# The IoU value is 0.6177290822355836

# %% [markdown]
# # Putting everything together (batch)

# %%
iou_results = []
for batch_idx, (filenames, anns, bboxes) in enumerate(test_loader):
  for i,(filename, annotation, bbox) in enumerate(zip(filenames, anns, bboxes)):
    result = yolo_model(filename)
    numpy_result = result.xyxy[0].detach().cpu().numpy()

  #Case where YOLO couldn't find any bounding box
    if len(numpy_result) == 0:
      iou_results.append(0)
      continue
    
    image = Image.open(filename)
    gold_bbox = [bbox[0], bbox[1], bbox[0]+bbox[2], bbox[1]+bbox[3]]


    #Using CLIP to find best crop
    #Computing crops
    croppings = []
    for bbox in numpy_result:
      croppings.append(image.crop((bbox[0], bbox[1], bbox[2], bbox[3])))

    # Encoding text
    text_inputs = torch.cat([clip.tokenize(annotation)]).to(device)
    with torch.no_grad():
      text_features = clip_model.encode_text(text_inputs)

    # Encoding image crops
    images_features = []
    #No need of for loop here 
    for img in croppings:
      image_input = preprocess(img).unsqueeze(0).to(device)
      with torch.no_grad():
        images_features.append(clip_model.encode_image(image_input.detach().clone()))

    #Bringing list of images into a tensor
    tensor_images_features = torch.stack(images_features).squeeze(1)

    #Computing cosine similarity
    best_bbox_indx = compute_cos_sim(tensor_images_features, text_features)

    #Evaluating with IoU
    predicted_bbox = [numpy_result[best_bbox_indx][0], numpy_result[best_bbox_indx][1], numpy_result[best_bbox_indx][2], numpy_result[best_bbox_indx][3]]
    iou = compute_IoU(predicted_bbox, gold_bbox)
    #print(f"Now evaluating image {i}/{BATCH_SIZE} of batch {batch_idx} \t Best crop is number {best_bbox_indx} \t and its iou is {iou}")
    iou_results.append(iou)

#Computing the mean of IoU
print(f"\nMean intersection over unit {np.mean(iou_results)}")

# %% [markdown]
# STOP

# %% [markdown]
# STOP

# %% [markdown]
# # Zero shot object detection
# link: https://www.youtube.com/watch?v=i3OYlaoj-BM

# %%
image_zero_shot = Image.open('dataset/refcocog/images/'+Custom_dataset.img_rep[110][0]['filename'])
image_zero_shot.show()
#Custom_dataset.img_rep[127][1]['filename']

# %%
from torchvision import transforms

transform = transforms.ToTensor()

img = transform(image_zero_shot)
img.data.shape

# %%
patches = img.data.unfold(0,3,3)
patches.shape

# %%
patch = 64
patches = patches.unfold(1, patch, patch)
patches.shape

# %%
patches = patches.unfold(2, patch, patch)
patches.shape

# %%
import matplotlib.pyplot as plt

X = patches.shape[1]
Y = patches.shape[2]

fig, ax = plt.subplots(X, Y, figsize=(Y*2, X*2))
for x in range(X):
  for y in range(Y):
    ax[x, y].imshow(patches[0,x,y].permute(1,2,0))
    ax[x, y].axis('off')
fig.tight_layout()
plt.show()
